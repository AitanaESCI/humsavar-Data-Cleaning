# %% [markdown]
# ## Variant data selection and preprocessing (__Humsavar__)

# %%
import json
import pandas as pd
import re
import requests
import time
from Bio.Data import IUPACData
from datetime import datetime
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_colwidth', None)

# %%
def parse_humsavar(file):
    """
    Parse humsavar.txt file content and extract the variant table into a pandas DataFrame.
    
    Parameters:
    file (str): humsavar.txt
    
    Returns:
    pandas.DataFrame: DataFrame containing the variant data with columns:
        - Main gene name
        - Swiss-Prot AC
        - FTId
        - AA change
        - Variant category
        - dbSNP
        - Disease name
    """
    # split content to lines
    lines = file.split('\n')

    # find start of the table
    table_start = None
    for i, line in enumerate(lines):
        if line.startswith('Main   '):
            table_start = i
            break
    
    if table_start is None:
        raise ValueError("Could not find the table header in the file")
    
    # skip header and underscores lines
    data_start = table_start + 2
    
    data = []
    for line in lines[data_start:]:
        if not line.strip():
            continue
            
        # split line into fields while preserving whitespace
        fields = re.split(r'\s{2,}', line.strip())
        
        # check all required fields have been correctly added
        if len(fields) >= 7:
            data.append({
                'Main gene name': fields[0],
                'Swiss-Prot AC': fields[1],
                'FTId': fields[2],
                'AA change': fields[3],
                'Variant category': fields[4],
                'dbSNP': fields[5],
                'Disease name': fields[6] if fields[6] != '-' else None
            })

    df = pd.DataFrame(data)
    return df

# %%
def read_and_parse_humsavar(file_path):
    """
    Read humsavar.txt file and parse it into a DataFrame.
    
    Parameters:
    file_path (str): Path to humsavar.txt
    
    Returns:
    pandas.DataFrame: DataFrame containing the data
    """
    with open(file_path, 'r') as file:
        content = file.read()
    return parse_humsavar(content)

# %% [markdown]
# We must read and process Humsavar files for __2025__ and __2021__.
#
# The source column is added to track the dataset origin and to distinguish variants after merging.

# %%
file = '../data/humsavar/humsavar_202501.txt'
data25 = read_and_parse_humsavar(file)
data25['Source']='2025'
data25.head()
# Out:
#   Main gene name Swiss-Prot AC        FTId    AA change Variant category  \
# 0           A1BG        P04217  VAR_018369   p.His52Arg             LB/B
# 1           A1BG        P04217  VAR_018370  p.His395Arg             LB/B
# 2           A1CF        Q9NQ94  VAR_052201  p.Val555Met             LB/B
# 3           A1CF        Q9NQ94  VAR_059821  p.Ala558Ser             LB/B
# 4            A2M        P01023  VAR_000012  p.Arg704His             LB/B
#
#         dbSNP Disease name Source
# 0    rs893184         None   2025
# 1   rs2241788         None   2025
# 2      rs9073         None   2025
# 3  rs11817448         None   2025
# 4   rs1800434         None   2025

# %%
len(data25)
# Out:
# 83697

# %%
data25["Main gene name"].nunique()
# Out:
# 13080

# %%
file = '../data/humsavar/humsavar_202102.txt'
data21 = read_and_parse_humsavar(file)
data21['Source']='2021'
data21.head()
# Out:
#   Main gene name Swiss-Prot AC        FTId    AA change Variant category  \
# 0           A1BG        P04217  VAR_018369   p.His52Arg             LB/B
# 1           A1BG        P04217  VAR_018370  p.His395Arg             LB/B
# 2           A1CF        Q9NQ94  VAR_052201  p.Val555Met             LB/B
# 3           A1CF        Q9NQ94  VAR_059821  p.Ala558Ser             LB/B
# 4            A2M        P01023  VAR_000012  p.Arg704His             LB/B
#
#         dbSNP Disease name Source
# 0    rs893184         None   2021
# 1   rs2241788         None   2021
# 2      rs9073         None   2021
# 3  rs11817448         None   2021
# 4   rs1800434         None   2021

# %%
len(data21)
# Out:
# 79192

# %%
data21["Main gene name"].nunique()
# Out:
# 12743

# %% [markdown]
# Strip whitespaces from columns.

# %%
compare_columns=['Main gene name', 'Swiss-Prot AC', 'AA change']
data25[compare_columns] = data25[compare_columns].apply(lambda x: x.str.strip())
data21[compare_columns] = data21[compare_columns].apply(lambda x: x.str.strip())

# %% [markdown]
# Now, we proceed to remove duplicate entries (for both 2025 and 2021).
#
# Many of the variants are already included in 2025, and as our goal is to keep the dataset with the __latest__ information, we remove possible duplicates.

# %%
print("Before removing duplicates: ", len(data25))
data25_1 = data25.drop_duplicates(subset=compare_columns).reset_index(drop=True)
print("After removing duplicates: ", len(data25_1))
# Out:
# Before removing duplicates:  83697
# After removing duplicates:  82585

# %%
print("Before removing duplicates: ", len(data21))
data21_1 = data21.drop_duplicates(subset=compare_columns).reset_index(drop=True)
print("After removing duplicates: ", len(data21_1))
# Out:
# Before removing duplicates:  79192
# After removing duplicates:  78192

# %%
# This is the difference in unique variants between 2025 and 2021.
len(data25_1) - len(data21_1)
# Out:
# 4393

# %%
# how many rows are in 2025 but not in 2021 based on compare_columns
diff_data = data25_1[~data25_1[compare_columns].apply(tuple, axis=1).isin(data21_1[compare_columns].apply(tuple, axis=1))]
print(f"Rows in 2025 but NOT in 2021: {len(diff_data)}")
# Out:
# Rows in 2025 but NOT in 2021: 6047

# %% [markdown]
# Clinical significance distribution of 2025 variants not in 2021.

# %%
diff_data['Variant category'].value_counts()
# Out:
# Variant category
# LP/P    2291
# US      2222
# LB/B    1534
# Name: count, dtype: int64

# %% [markdown]
# We keep only LP/P (Likely Pathogenic/Pathogenic) and LB/B (Likely Benign/Benign) variants. With this we aim to remove VUS.

# %%
data25_2 = diff_data[diff_data['Variant category'].isin(['LP/P','LB/B'])].reset_index(drop=True)

# %%
data25_2['Variant category'].value_counts()
# Out:
# Variant category
# LP/P    2291
# LB/B    1534
# Name: count, dtype: int64

# %%
# how many genes we have
data25_2['Main gene name'].nunique()
# Out:
# 1258

# %%
data25_2['Swiss-Prot AC'].nunique()
# Out:
# 1258

# %%
data25_2.head()
# Out:
#   Main gene name Swiss-Prot AC        FTId     AA change Variant category  \
# 0          AARS1        P49588  VAR_089576   p.Arg326Trp             LP/P
# 1          AARS1        P49588  VAR_089577   p.Thr606Ile             LP/P
# 2          AARS1        P49588  VAR_089578   p.Ser698Phe             LP/P
# 3          ABCA4        P78363  VAR_084908  p.Asp1102Tyr             LB/B
# 4          ABCA4        P78363  VAR_084916  p.Gly1203Asp             LP/P
#
#          dbSNP                                       Disease name Source
# 0            -  Charcot-Marie-Tooth disease, axonal, 2N (CMT2N...   2025
# 1            -  Leukoencephalopathy, hereditary diffuse, with ...   2025
# 2            -  Charcot-Marie-Tooth disease, axonal, 2N (CMT2N...   2025
# 3  rs138641544                                               None   2025
# 4            -           Stargardt disease 1 (STGD1) [MIM:248200]   2025

# %% [markdown]
# Exclude entries where the gene name corresponds to a dash

# %%
data25_2 = data25_2[data25_2['Main gene name']!='-'].reset_index(drop=True)

# %% [markdown]
# Check if there are accession numbers that do not have the expected length of 6.

# %%
[uni for uni in data25_2['Swiss-Prot AC'].unique() if len(uni)!= 6]
# Out:
# []

# %% [markdown]
# As with ClinVar dataset, we convert Aa changes to 1 letter notation.

# %%
def convert_to_one_letter(aa_change):
    prefix, from_aa, position, to_aa = (
        aa_change[0:2],  # e.g., 'p.'
        aa_change[2:5],  # e.g., 'Arg'
        ''.join(filter(str.isdigit, aa_change)),  # e.g., '326'
        aa_change[-3:]  # e.g., 'Trp'
    )

    # convert to 1 letter code
    from_aa_one = IUPACData.protein_letters_3to1.get(from_aa, '?')
    to_aa_one = IUPACData.protein_letters_3to1.get(to_aa, '?')
    return f"{from_aa_one}{position}{to_aa_one}"

# %%
data25_2['Variant'] = data25_2['AA change'].apply(convert_to_one_letter)

# %% [markdown]
# And we assign binary clinical significance.

# %%
data25_2.loc[data25_2['Variant category']=='LB/B','BinaryClinicalSignificance'] = 'B'
data25_2.loc[data25_2['Variant category']=='LP/P','BinaryClinicalSignificance'] = 'P'

# %%
data25_2.BinaryClinicalSignificance.value_counts()
# Out:
# BinaryClinicalSignificance
# P    2291
# B    1533
# Name: count, dtype: int64

# %%
data25_2['Main gene name'].nunique()
# Out:
# 1257

# %% [markdown]
# Filter duplicated dbSNP entries.

# %%
data25_2[data25_2.duplicated(subset=['dbSNP'], keep=False)].dbSNP.unique()
# Out:
# array(['-', 'rs1645264815', 'rs2153228682', 'rs1705222655', 'rs752450983',
#        'rs1599011050', 'rs1949512456', 'rs28642966', 'rs201552310',
#        'rs200005406', 'rs2072648', 'rs1057517926', 'rs1757708758',
#        'rs77834747', 'rs381427', 'rs421016', 'rs121908310', 'rs77933015',
#        'rs121908308', 'rs782199122', 'rs1191455921', 'rs2071312',
#        'rs104894264', 'rs7480563', 'rs7126405', 'rs2293232', 'rs2246901',
#        'rs200291894', 'rs571714796', 'rs7255187', 'rs1684813071',
#        'rs1554297905', 'rs1838076782', 'rs141269120', 'rs1057149',
#        'rs1385657144', 'rs1965499910'], dtype=object)

# %%
# use first output as example
data25_2[data25_2.dbSNP=='rs1645264815']
# Out:
#     Main gene name Swiss-Prot AC        FTId    AA change Variant category  \
# 119           AGO1        Q9UL18  VAR_088408  p.Leu190Pro             LP/P
# 120           AGO1        Q9UL18  VAR_088409  p.Leu190Arg             LP/P
#
#             dbSNP                                       Disease name Source  \
# 119  rs1645264815  Neurodevelopmental disorder with language dela...   2025
# 120  rs1645264815  Neurodevelopmental disorder with language dela...   2025
#
#     Variant BinaryClinicalSignificance
# 119   L190P                          P
# 120   L190R                          P

# %%
data25_2.to_csv('../data/humsavar/humsavar_20212025.csv', index=0)

# %% [markdown]
# We add more information to the dataset by retrieving .json files from Uniprot.
#
# MANE-Select (Matched Annotation from NCBI and EMBL-EBI) provides a single annotated transcript per gene, thus giving consistency between RefSeq and Ensembl. The addition of MANE-Select data helps standardize variant annotations.
#
# With this we aim to link variants to a reliable reference transcript.

# %%
def extract_mane_select_info(humsavar_df, uniprot_id_column="Swiss-Prot AC", 
                           cache_dir="uniprot_cache", 
                           rate_limit_delay=0.1,
                           batch_size=100):
    """
    Extracts MANE-Select information for each UniProt ID with caching and rate limiting.
    
    Args:
        humsavar_df (pd.DataFrame): DataFrame containing UniProt IDs
        uniprot_id_column (str): Name of the column containing UniProt IDs
        cache_dir (str): Directory to store cached responses
        rate_limit_delay (float): Delay between API calls in seconds
        batch_size (int): Number of proteins to process before saving interim results
    
    Returns:
        pd.DataFrame: DataFrame with MANE-Select information
    """

    cache_path = Path(cache_dir)
    cache_path.mkdir(parents=True, exist_ok=True)
    log_file = cache_path / f"extraction_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
    
    def log_message(message):
        """Write message to log file and print it"""
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        log_message = f"[{timestamp}] {message}"
        print(log_message)
        with open(log_file, "a") as f:
            f.write(log_message + "\n")

    def get_cached_response(uniprot_id):
        """Get cached response for a UniProt ID"""
        cache_file = cache_path / f"{uniprot_id}.json"
        if cache_file.exists():
            try:
                with open(cache_file, "r") as f:
                    return json.load(f)
            except json.JSONDecodeError:
                return None
        return None
    
    def cache_response(uniprot_id, data):
        """Cache response for a UniProt ID"""
        cache_file = cache_path / f"{uniprot_id}.json"
        with open(cache_file, "w") as f:
            json.dump(data, f)
    
    def process_uniprot_id(uniprot_id):
        """Process a single UniProt ID"""
        cached_data = get_cached_response(uniprot_id)
        if cached_data is not None:
            data = cached_data
            log_message(f"Using cached data for {uniprot_id}")
        else:
            try:
                # Fetch JSON data from UniProt API
                json_url = f"https://rest.uniprot.org/uniprotkb/{uniprot_id}.json"
                response = requests.get(json_url)
                response.raise_for_status()
                data = response.json()
                # Cache the response
                cache_response(uniprot_id, data)
                log_message(f"Fetched and cached data for {uniprot_id}")
                # Rate limiting
                time.sleep(rate_limit_delay)
            except Exception as e:
                log_message(f"Error fetching data for {uniprot_id}: {str(e)}")
                return {
                    'Swiss-Prot AC': uniprot_id,
                    'MANE-Select ID': None,
                    'Ensembl ID': None,
                    'Protein ID': None,
                    'RefSeq Nucleotide ID': None,
                    'RefSeq Protein ID': None,
                    'Error': str(e)
                }
        
        try:
            # Search for MANE-Select information
            mane_select_info = None
            for entry in data.get('uniProtKBCrossReferences', []):
                if entry.get('database') == 'MANE-Select':
                    mane_select_info = entry
                    break
            
            if mane_select_info:
                mane_id = mane_select_info['id']
                ensembl_id = mane_select_info['id'].split('.')[0]
                protein_id = next(
                    (prop['value'] for prop in mane_select_info['properties'] 
                     if prop['key'] == 'ProteinId'), None)
                refseq_nucleotide_id = next(
                    (prop['value'] for prop in mane_select_info['properties'] 
                     if prop['key'] == 'RefSeqNucleotideId'), None)
                refseq_protein_id = next(
                    (prop['value'] for prop in mane_select_info['properties'] 
                     if prop['key'] == 'RefSeqProteinId'), None)
            else:
                mane_id = ensembl_id = protein_id = refseq_nucleotide_id = refseq_protein_id = None
            
            return {
                'Swiss-Prot AC': uniprot_id,
                'MANE-Select ID': mane_id,
                'Ensembl ID': ensembl_id,
                'Protein ID': protein_id,
                'RefSeq Nucleotide ID': refseq_nucleotide_id,
                'RefSeq Protein ID': refseq_protein_id,
                'Error': None
            }
        except Exception as e:
            log_message(f"Error processing data for {uniprot_id}: {str(e)}")
            return {
                'Swiss-Prot AC': uniprot_id,
                'MANE-Select ID': None,
                'Ensembl ID': None,
                'Protein ID': None,
                'RefSeq Nucleotide ID': None,
                'RefSeq Protein ID': None,
                'Error': str(e)
            }

    results = []
    total_ids = len(humsavar_df[uniprot_id_column].unique())
    log_message(f"Starting processing of {total_ids} Uniprot IDs")
    
    for i, uniprot_id in enumerate(humsavar_df[uniprot_id_column].unique(), 1):
        result = process_uniprot_id(uniprot_id)
        results.append(result)

        if i % batch_size == 0:
            interim_df = pd.DataFrame(results)
            interim_file = cache_path / f"interim_results_{i}.csv"
            interim_df.to_csv(interim_file, index=False)
            log_message(f"Processed {i}/{total_ids} IDs. Saved results to {interim_file}")

    mane_select_df = pd.DataFrame(results)

    final_file = cache_path/"final_results.csv"
    mane_select_df.to_csv(final_file, index=False)
    log_message(f"Final results saved to {final_file}")
    return mane_select_df

# %%
data25_2 = pd.read_csv('../data/humsavar/humsavar_20212025.csv')

# %% [markdown]
# Retrieve and add MANE-Select transcript mappings to the dataset.

# %%
mane_results = extract_mane_select_info(
    data25_2,
    cache_dir="uniprot_cache",  # store API responses
    rate_limit_delay=0.1,       # delay between API calls in seconds
    batch_size=100              # save results every 100 proteins
)
# Out:
# [2025-03-18 16:45:29] Starting processing of 1257 Uniprot IDs
# [2025-03-18 16:45:29] Using cached data for P49588
# [2025-03-18 16:45:29] Using cached data for P78363
# [2025-03-18 16:45:29] Using cached data for Q9NP58
# [2025-03-18 16:45:29] Using cached data for O14678
# [2025-03-18 16:45:29] Using cached data for Q96SE0
# [2025-03-18 16:45:29] Using cached data for O95870
# [2025-03-18 16:45:29] Using cached data for A6QL63
# [2025-03-18 16:45:29] Using cached data for P25106
# [2025-03-18 16:45:29] Using cached data for A6NK06
# [2025-03-18 16:45:29] Using cached data for Q3I5F7
# [2025-03-18 16:45:29] Using cached data for Q9ULC5
# [2025-03-18 16:45:29] Using cached data for P68133
# [2025-03-18 16:45:29] Using cached data for P62736
# [2025-03-18 16:45:29] Using cached data for P60709
# [2025-03-18 16:45:29] Using cached data for P63267
# [2025-03-18 16:45:29] Using cached data for Q8TC94
# [2025-03-18 16:45:29] Using cached data for P35609
# [2025-03-18 16:45:29] Using cached data for O60266
# [2025-03-18 16:45:29] Using cached data for O95622
# [2025-03-18 16:45:29] Using cached data for Q8IZF7
# [2025-03-18 16:45:29] Using cached data for O94910
# [2025-03-18 16:45:29] Using cached data for P00325
# [2025-03-18 16:45:29] Using cached data for P11766
# [2025-03-18 16:45:29] Using cached data for P08588
# [2025-03-18 16:45:29] Using cached data for P51826
# [2025-03-18 16:45:29] Using cached data for Q8NB90
# [2025-03-18 16:45:29] Using cached data for Q9BVQ7
# [2025-03-18 16:45:29] Using cached data for Q9Y4W6
# [2025-03-18 16:45:29] Using cached data for Q9UL18
# [2025-03-18 16:45:29] Using cached data for Q9UKV8
# [2025-03-18 16:45:29] Using cached data for O95994
# [2025-03-18 16:45:29] Using cached data for P01019
# [2025-03-18 16:45:29] Using cached data for P23526
# [2025-03-18 16:45:29] Using cached data for Q5TGY3
# [2025-03-18 16:45:29] Using cached data for P0C7V0
# [2025-03-18 16:45:29] Using cached data for O00170
# [2025-03-18 16:45:29] Using cached data for Q5JQC9
# [2025-03-18 16:45:29] Using cached data for Q5T2L2
# [2025-03-18 16:45:29] Using cached data for O94788
# [2025-03-18 16:45:29] Using cached data for P30837
# [2025-03-18 16:45:29] Using cached data for Q9NP73
# [2025-03-18 16:45:29] Using cached data for Q96F25
# [2025-03-18 16:45:29] Using cached data for Q9Y673
# [2025-03-18 16:45:29] Using cached data for Q6NS38
# [2025-03-18 16:45:29] Using cached data for Q96QP1
# [2025-03-18 16:45:29] Using cached data for Q96L96
# [2025-03-18 16:45:29] Using cached data for P05186
# [2025-03-18 16:45:29] Using cached data for P23109
# [2025-03-18 16:45:29] Using cached data for Q01433
# [2025-03-18 16:45:29] Using cached data for P03950
# [2025-03-18 16:45:29] Using cached data for Q15389
# [2025-03-18 16:45:29] Using cached data for O15123
# [2025-03-18 16:45:29] Using cached data for Q8N957
# [2025-03-18 16:45:29] Using cached data for Q9HCJ1
# [2025-03-18 16:45:29] Using cached data for O75179
# [2025-03-18 16:45:29] Using cached data for Q6NSI1
# [2025-03-18 16:45:29] Using cached data for Q8N283
# [2025-03-18 16:45:29] Using cached data for O43423
# [2025-03-18 16:45:29] Using cached data for P50995
# [2025-03-18 16:45:29] Using cached data for Q10567
# [2025-03-18 16:45:29] Using cached data for O43747
# [2025-03-18 16:45:29] Using cached data for P04114
# [2025-03-18 16:45:29] Using cached data for Q9BQE5
# [2025-03-18 16:45:29] Using cached data for Q96LR9
# [2025-03-18 16:45:29] Using cached data for P55087
# [2025-03-18 16:45:29] Using cached data for P55064
# [2025-03-18 16:45:29] Using cached data for Q8WUF8
# [2025-03-18 16:45:29] Using cached data for Q9Y6D6
# [2025-03-18 16:45:29] Using cached data for Q5TG30
# [2025-03-18 16:45:29] Using cached data for Q9HCE6
# [2025-03-18 16:45:29] Using cached data for Q8NFD5
# [2025-03-18 16:45:29] Using cached data for Q3SXY8
# [2025-03-18 16:45:29] Using cached data for P36404
# [2025-03-18 16:45:29] Using cached data for Q8WVX3
# [2025-03-18 16:45:29] Using cached data for P59998
# [2025-03-18 16:45:29] Using cached data for Q6UWY0
# [2025-03-18 16:45:29] Using cached data for Q93070
# [2025-03-18 16:45:29] Using cached data for Q495Z4
# [2025-03-18 16:45:29] Using cached data for Q96Q27
# [2025-03-18 16:45:29] Using cached data for P50553
# [2025-03-18 16:45:29] Using cached data for Q9NQ33
# [2025-03-18 16:45:29] Using cached data for Q96FT7
# [2025-03-18 16:45:29] Using cached data for P04424
# [2025-03-18 16:45:29] Using cached data for Q53RT3
# [2025-03-18 16:45:29] Using cached data for Q9NVI7
# [2025-03-18 16:45:29] Using cached data for O95352
# [2025-03-18 16:45:29] Using cached data for Q32MH5
# [2025-03-18 16:45:29] Using cached data for P98196
# [2025-03-18 16:45:29] Using cached data for Q9H7F0
# [2025-03-18 16:45:29] Using cached data for P50993
# [2025-03-18 16:45:29] Using cached data for P13637
# [2025-03-18 16:45:29] Using cached data for P20020
# [2025-03-18 16:45:29] Using cached data for Q16720
# [2025-03-18 16:45:29] Using cached data for P25705
# [2025-03-18 16:45:29] Using cached data for P06576
# [2025-03-18 16:45:29] Using cached data for P48201
# [2025-03-18 16:45:29] Using cached data for Q93050
# [2025-03-18 16:45:29] Using cached data for P27449
# [2025-03-18 16:45:29] Using cached data for P46100
# [2025-03-18 16:45:29] Using cached data for O14965
# [2025-03-18 16:45:29] Processed 100/1257 IDs. Saved results to uniprot_cache/interim_results_100.csv
# [2025-03-18 16:45:29] Using cached data for Q9Y2T1
# [2025-03-18 16:45:29] Using cached data for Q67FW5
# [2025-03-18 16:45:29] Using cached data for Q8NHY0
# [2025-03-18 16:45:29] Using cached data for P15291
# [2025-03-18 16:45:29] Using cached data for Q92560
# [2025-03-18 16:45:29] Using cached data for Q9BXC9
# [2025-03-18 16:45:29] Using cached data for Q9H6U6
# [2025-03-18 16:45:29] Using cached data for O15382
# [2025-03-18 16:45:29] Using cached data for P12694
# [2025-03-18 16:45:29] Using cached data for Q5H9F3
# [2025-03-18 16:45:29] Using cached data for Q2LD37
# [2025-03-18 16:45:29] Using cached data for Q14667
# [2025-03-18 16:45:29] Using cached data for Q6BDS2
# [2025-03-18 16:45:29] Using cached data for A0JNW5
# [2025-03-18 16:45:29] Using cached data for Q8WYA1
# [2025-03-18 16:45:29] Using cached data for P22004
# [2025-03-18 16:45:29] Using cached data for P59826
# [2025-03-18 16:45:29] Using cached data for P51587
# [2025-03-18 16:45:29] Using cached data for O60885
# [2025-03-18 16:45:29] Using cached data for P35613
# [2025-03-18 16:45:29] Using cached data for Q8WZ55
# [2025-03-18 16:45:29] Using cached data for Q5XKL5
# [2025-03-18 16:45:29] Using cached data for Q9NY30
# [2025-03-18 16:45:29] Using cached data for Q5SQS8
# [2025-03-18 16:45:29] Using cached data for Q9NWQ9
# [2025-03-18 16:45:29] Using cached data for Q2M2W7
# [2025-03-18 16:45:29] Using cached data for Q9NSK7
# [2025-03-18 16:45:29] Using cached data for Q96EU7
# [2025-03-18 16:45:29] Using cached data for Q5SNV9
# [2025-03-18 16:45:29] Using cached data for Q9BQM9
# [2025-03-18 16:45:29] Using cached data for Q96LM9
# [2025-03-18 16:45:29] Using cached data for Q6ZRC1
# [2025-03-18 16:45:29] Using cached data for P07358
# [2025-03-18 16:45:29] Using cached data for O00555
# [2025-03-18 16:45:29] Using cached data for Q13936
# [2025-03-18 16:45:29] Using cached data for O95180
# [2025-03-18 16:45:29] Using cached data for Q9P0X4
# [2025-03-18 16:45:29] Using cached data for Q13698
# [2025-03-18 16:45:29] Using cached data for P54289
# [2025-03-18 16:45:29] Using cached data for Q8N126
# [2025-03-18 16:45:29] Using cached data for P30988
# [2025-03-18 16:45:29] Using cached data for Q16602
# [2025-03-18 16:45:29] Using cached data for Q14444
# [2025-03-18 16:45:29] Using cached data for Q9BXY5
# [2025-03-18 16:45:29] Using cached data for Q9Y2G2
# [2025-03-18 16:45:29] Using cached data for Q9H257
# [2025-03-18 16:45:29] Using cached data for Q7Z7H3
# [2025-03-18 16:45:29] Using cached data for Q13191
# [2025-03-18 16:45:29] Using cached data for Q9P2K1
# [2025-03-18 16:45:29] Using cached data for Q6NUI1
# [2025-03-18 16:45:29] Using cached data for Q8NDH2
# [2025-03-18 16:45:29] Using cached data for Q6NSX1
# [2025-03-18 16:45:29] Using cached data for Q13939
# [2025-03-18 16:45:29] Using cached data for Q16663
# [2025-03-18 16:45:29] Using cached data for P55773
# [2025-03-18 16:45:29] Using cached data for P41002
# [2025-03-18 16:45:29] Using cached data for P41597
# [2025-03-18 16:45:29] Using cached data for Q8TD46
# [2025-03-18 16:45:29] Using cached data for P10747
# [2025-03-18 16:45:29] Using cached data for Q9Y5K6
# [2025-03-18 16:45:29] Using cached data for Q12834
# [2025-03-18 16:45:29] Using cached data for O60508
# [2025-03-18 16:45:29] Using cached data for Q9Y5S2
# [2025-03-18 16:45:29] Using cached data for P55287
# [2025-03-18 16:45:29] Using cached data for P19022
# [2025-03-18 16:45:29] Using cached data for Q9BWU1
# [2025-03-18 16:45:29] Using cached data for Q00532
# [2025-03-18 16:45:29] Using cached data for Q15517
# [2025-03-18 16:45:29] Using cached data for Q3KPI0
# [2025-03-18 16:45:29] Using cached data for P06731
# [2025-03-18 16:45:29] Using cached data for P40199
# [2025-03-18 16:45:29] Using cached data for Q14002
# [2025-03-18 16:45:29] Using cached data for Q15744
# [2025-03-18 16:45:29] Using cached data for O95319
# [2025-03-18 16:45:29] Using cached data for Q9P2H0
# [2025-03-18 16:45:29] Using cached data for Q9C0D2
# [2025-03-18 16:45:29] Using cached data for Q5JTW2
# [2025-03-18 16:45:29] Using cached data for Q2M329
# [2025-03-18 16:45:29] Using cached data for Q9H0I3
# [2025-03-18 16:45:29] Using cached data for Q5T5A4
# [2025-03-18 16:45:29] Using cached data for Q8IV35
# [2025-03-18 16:45:29] Using cached data for Q96NL8
# [2025-03-18 16:45:29] Using cached data for Q8N1V2
# [2025-03-18 16:45:29] Using cached data for Q9H5F2
# [2025-03-18 16:45:29] Using cached data for A4QMS7
# [2025-03-18 16:45:29] Using cached data for Q9P2M7
# [2025-03-18 16:45:29] Using cached data for Q86WJ1
# [2025-03-18 16:45:29] Using cached data for Q8TDI0
# [2025-03-18 16:45:29] Using cached data for O14757
# [2025-03-18 16:45:29] Using cached data for P35790
# [2025-03-18 16:45:29] Using cached data for P02708
# [2025-03-18 16:45:29] Using cached data for O76071
# [2025-03-18 16:45:29] Using cached data for A1XBS5
# [2025-03-18 16:45:29] Using cached data for Q96RK0
# [2025-03-18 16:45:29] Using cached data for Q8IXM7
# [2025-03-18 16:45:29] Using cached data for Q3SX64
# [2025-03-18 16:45:29] Using cached data for Q3ZCV2
# [2025-03-18 16:45:29] Using cached data for Q8TCI5
# [2025-03-18 16:45:29] Using cached data for Q9H1P6
# [2025-03-18 16:45:29] Using cached data for A6NJV1
# [2025-03-18 16:45:29] Processed 200/1257 IDs. Saved results to uniprot_cache/interim_results_200.csv
# [2025-03-18 16:45:29] Using cached data for Q8N5S3
# [2025-03-18 16:45:29] Using cached data for Q96S66
# [2025-03-18 16:45:29] Using cached data for P51788
# [2025-03-18 16:45:29] Using cached data for P51790
# [2025-03-18 16:45:29] Using cached data for P51797
# [2025-03-18 16:45:29] Using cached data for P51801
# [2025-03-18 16:45:29] Using cached data for Q9Y5I7
# [2025-03-18 16:45:29] Using cached data for Q8N6F1
# [2025-03-18 16:45:29] Using cached data for P05452
# [2025-03-18 16:45:29] Using cached data for P49761
# [2025-03-18 16:45:29] Using cached data for Q9H078
# [2025-03-18 16:45:29] Using cached data for A0PK11
# [2025-03-18 16:45:29] Using cached data for P46091
# [2025-03-18 16:45:29] Using cached data for Q96KN2
# [2025-03-18 16:45:29] Using cached data for P29973
# [2025-03-18 16:45:29] Using cached data for Q14028
# [2025-03-18 16:45:29] Using cached data for P02452
# [2025-03-18 16:45:29] Using cached data for P08123
# [2025-03-18 16:45:29] Using cached data for P02461
# [2025-03-18 16:45:29] Using cached data for P20908
# [2025-03-18 16:45:29] Using cached data for P49747
# [2025-03-18 16:45:29] Using cached data for P53618
# [2025-03-18 16:45:29] Using cached data for Q9Y678
# [2025-03-18 16:45:29] Using cached data for Q96H96
# [2025-03-18 16:45:29] Using cached data for Q9Y3A0
# [2025-03-18 16:45:29] Using cached data for Q99807
# [2025-03-18 16:45:29] Using cached data for P00450
# [2025-03-18 16:45:29] Using cached data for Q9HC77
# [2025-03-18 16:45:29] Using cached data for Q9H799
# [2025-03-18 16:45:29] Using cached data for P36551
# [2025-03-18 16:45:29] Using cached data for Q9UKF6
# [2025-03-18 16:45:29] Using cached data for Q68CJ9
# [2025-03-18 16:45:29] Using cached data for Q96HD1
# [2025-03-18 16:45:29] Using cached data for P13385
# [2025-03-18 16:45:29] Using cached data for Q9UJA2
# [2025-03-18 16:45:29] Using cached data for Q5TZA2
# [2025-03-18 16:45:29] Using cached data for P02489
# [2025-03-18 16:45:29] Using cached data for Q9Y4K1
# [2025-03-18 16:45:29] Using cached data for Q8TDX6
# [2025-03-18 16:45:29] Using cached data for Q8N6G5
# [2025-03-18 16:45:29] Using cached data for P33240
# [2025-03-18 16:45:29] Using cached data for Q8WYA6
# [2025-03-18 16:45:29] Using cached data for Q9P2B4
# [2025-03-18 16:45:29] Using cached data for O60494
# [2025-03-18 16:45:29] Using cached data for Q13618
# [2025-03-18 16:45:29] Using cached data for Q9NQC7
# [2025-03-18 16:45:29] Using cached data for P08686
# [2025-03-18 16:45:29] Using cached data for P33261
# [2025-03-18 16:45:29] Using cached data for Q16850
# [2025-03-18 16:45:29] Using cached data for P14920
# [2025-03-18 16:45:29] Using cached data for Q8N136
# [2025-03-18 16:45:29] Using cached data for Q9UK59
# [2025-03-18 16:45:29] Using cached data for P11182
# [2025-03-18 16:45:29] Using cached data for Q9H816
# [2025-03-18 16:45:29] Using cached data for P40126
# [2025-03-18 16:45:29] Using cached data for Q16531
# [2025-03-18 16:45:29] Using cached data for Q99489
# [2025-03-18 16:45:29] Using cached data for Q9Y2R4
# [2025-03-18 16:45:29] Using cached data for Q9H4E7
# [2025-03-18 16:45:29] Using cached data for O75140
# [2025-03-18 16:45:29] Using cached data for Q6PKH6
# [2025-03-18 16:45:29] Using cached data for Q8N5I4
# [2025-03-18 16:45:29] Using cached data for Q96HY7
# [2025-03-18 16:45:29] Using cached data for Q9UPY3
# [2025-03-18 16:45:29] Using cached data for P49895
# [2025-03-18 16:45:29] Using cached data for O60832
# [2025-03-18 16:45:29] Using cached data for Q99766
# [2025-03-18 16:45:29] Using cached data for P11532
# [2025-03-18 16:45:29] Using cached data for P51530
# [2025-03-18 16:45:29] Using cached data for Q96MX6
# [2025-03-18 16:45:29] Using cached data for Q86X45
# [2025-03-18 16:45:29] Using cached data for Q8IYS4
# [2025-03-18 16:45:29] Using cached data for Q5TEA3
# [2025-03-18 16:45:29] Using cached data for Q9P2D7
# [2025-03-18 16:45:29] Using cached data for Q8IVF4
# [2025-03-18 16:45:29] Using cached data for Q9P225
# [2025-03-18 16:45:29] Using cached data for Q96JB1
# [2025-03-18 16:45:29] Using cached data for Q6TDU7
# [2025-03-18 16:45:29] Using cached data for Q9UDY4
# [2025-03-18 16:45:29] Using cached data for Q96LL9
# [2025-03-18 16:45:29] Using cached data for O00115
# [2025-03-18 16:45:29] Using cached data for Q96M86
# [2025-03-18 16:45:29] Using cached data for Q5JSL3
# [2025-03-18 16:45:29] Using cached data for Q5T8R8
# [2025-03-18 16:45:29] Using cached data for Q9BU89
# [2025-03-18 16:45:29] Using cached data for Q9UPQ8
# [2025-03-18 16:45:29] Using cached data for Q8TEK3
# [2025-03-18 16:45:29] Using cached data for Q9BZG8
# [2025-03-18 16:45:29] Using cached data for Q9BQC3
# [2025-03-18 16:45:29] Using cached data for Q9H2P9
# [2025-03-18 16:45:29] Using cached data for P27487
# [2025-03-18 16:45:29] Using cached data for Q86TI2
# [2025-03-18 16:45:29] Using cached data for Q6NUT2
# [2025-03-18 16:45:29] Using cached data for Q6ZN68
# [2025-03-18 16:45:29] Using cached data for Q9BPU6
# [2025-03-18 16:45:29] Using cached data for Q494R4
# [2025-03-18 16:45:29] Using cached data for P35462
# [2025-03-18 16:45:29] Using cached data for Q9Y295
# [2025-03-18 16:45:29] Using cached data for P23919
# [2025-03-18 16:45:29] Using cached data for Q6B8I1
# [2025-03-18 16:45:29] Processed 300/1257 IDs. Saved results to uniprot_cache/interim_results_300.csv
# [2025-03-18 16:45:29] Using cached data for Q9UII6
# [2025-03-18 16:45:29] Using cached data for P33316
# [2025-03-18 16:45:29] Using cached data for Q5JR98
# [2025-03-18 16:45:29] Using cached data for Q86YF9
# [2025-03-18 16:45:29] Using cached data for Q92838
# [2025-03-18 16:45:29] Using cached data for Q8WVE0
# [2025-03-18 16:45:29] Using cached data for Q5JPI9
# [2025-03-18 16:45:29] Using cached data for Q96AZ1
# [2025-03-18 16:45:29] Using cached data for P0DPD7
# [2025-03-18 16:45:29] Using cached data for Q12805
# [2025-03-18 16:45:29] Using cached data for P19525
# [2025-03-18 16:45:29] Using cached data for Q9NZJ5
# [2025-03-18 16:45:29] Using cached data for P41091
# [2025-03-18 16:45:29] Using cached data for Q14240
# [2025-03-18 16:45:29] Using cached data for P63241
# [2025-03-18 16:45:29] Using cached data for Q99607
# [2025-03-18 16:45:29] Using cached data for Q14241
# [2025-03-18 16:45:29] Using cached data for O95163
# [2025-03-18 16:45:29] Using cached data for Q8TE02
# [2025-03-18 16:45:29] Using cached data for Q9Y6C2
# [2025-03-18 16:45:29] Using cached data for Q6UWV6
# [2025-03-18 16:45:29] Using cached data for Q15884
# [2025-03-18 16:45:29] Using cached data for O60320
# [2025-03-18 16:45:29] Using cached data for P81408
# [2025-03-18 16:45:29] Using cached data for P04626
# [2025-03-18 16:45:29] Using cached data for P21860
# [2025-03-18 16:45:29] Using cached data for Q5T890
# [2025-03-18 16:45:29] Using cached data for Q8IV48
# [2025-03-18 16:45:29] Using cached data for O94905
# [2025-03-18 16:45:29] Using cached data for Q8N2X6
# [2025-03-18 16:45:29] Using cached data for Q2M3D2
# [2025-03-18 16:45:29] Using cached data for Q9Y3B2
# [2025-03-18 16:45:29] Using cached data for Q9NQT4
# [2025-03-18 16:45:29] Using cached data for Q8NEV8
# [2025-03-18 16:45:29] Using cached data for P00488
# [2025-03-18 16:45:29] Using cached data for P08709
# [2025-03-18 16:45:29] Using cached data for P12104
# [2025-03-18 16:45:29] Using cached data for Q6P587
# [2025-03-18 16:45:29] Using cached data for Q5T035
# [2025-03-18 16:45:29] Using cached data for Q5T036
# [2025-03-18 16:45:29] Using cached data for Q9NX05
# [2025-03-18 16:45:29] Using cached data for Q8N8A8
# [2025-03-18 16:45:29] Using cached data for Q8N0U4
# [2025-03-18 16:45:29] Using cached data for Q8IZ13
# [2025-03-18 16:45:29] Using cached data for Q14320
# [2025-03-18 16:45:29] Using cached data for Q8WVX9
# [2025-03-18 16:45:29] Using cached data for P62861
# [2025-03-18 16:45:29] Using cached data for O00757
# [2025-03-18 16:45:29] Using cached data for Q8N531
# [2025-03-18 16:45:29] Using cached data for Q9NVF7
# [2025-03-18 16:45:29] Using cached data for O95170
# [2025-03-18 16:45:29] Using cached data for Q9UKB1
# [2025-03-18 16:45:29] Using cached data for Q969H0
# [2025-03-18 16:45:29] Using cached data for O75015
# [2025-03-18 16:45:29] Using cached data for O14526
# [2025-03-18 16:45:29] Using cached data for Q6P4F2
# [2025-03-18 16:45:29] Using cached data for P22570
# [2025-03-18 16:45:29] Using cached data for Q96JP0
# [2025-03-18 16:45:29] Using cached data for Q96M78
# [2025-03-18 16:45:29] Using cached data for Q9NQ89
# [2025-03-18 16:45:29] Using cached data for Q92913
# [2025-03-18 16:45:29] Using cached data for Q8N612
# [2025-03-18 16:45:29] Using cached data for Q5W0V3
# [2025-03-18 16:45:29] Using cached data for Q86V87
# [2025-03-18 16:45:29] Using cached data for Q9NSG2
# [2025-03-18 16:45:29] Using cached data for Q5D862
# [2025-03-18 16:45:29] Using cached data for Q13045
# [2025-03-18 16:45:29] Using cached data for Q14315
# [2025-03-18 16:45:29] Using cached data for Q9UPI3
# [2025-03-18 16:45:29] Using cached data for Q5VW36
# [2025-03-18 16:45:29] Using cached data for A8MTJ6
# [2025-03-18 16:45:29] Using cached data for Q5SZK8
# [2025-03-18 16:45:29] Using cached data for C9JXX5
# [2025-03-18 16:45:29] Using cached data for Q7Z6J6
# [2025-03-18 16:45:29] Using cached data for P0C7T7
# [2025-03-18 16:45:29] Using cached data for Q8NDD1
# [2025-03-18 16:45:29] Using cached data for P23945
# [2025-03-18 16:45:29] Using cached data for Q9UET6
# [2025-03-18 16:45:29] Using cached data for P09958
# [2025-03-18 16:45:29] Using cached data for P21217
# [2025-03-18 16:45:29] Using cached data for Q9UM11
# [2025-03-18 16:45:29] Using cached data for P11413
# [2025-03-18 16:45:29] Using cached data for P60520
# [2025-03-18 16:45:29] Using cached data for Q9UBS5
# [2025-03-18 16:45:29] Using cached data for P34903
# [2025-03-18 16:45:29] Using cached data for Q9UN88
# [2025-03-18 16:45:29] Using cached data for Q99259
# [2025-03-18 16:45:29] Using cached data for A6NGK3
# [2025-03-18 16:45:29] Using cached data for A6NER3
# [2025-03-18 16:45:29] Using cached data for Q14376
# [2025-03-18 16:45:29] Using cached data for Q6NXP2
# [2025-03-18 16:45:29] Using cached data for Q96KD3
# [2025-03-18 16:45:29] Using cached data for Q8TC56
# [2025-03-18 16:45:29] Using cached data for Q8IYT1
# [2025-03-18 16:45:29] Using cached data for Q6IPT2
# [2025-03-18 16:45:29] Using cached data for Q8NEG0
# [2025-03-18 16:45:29] Using cached data for P41250
# [2025-03-18 16:45:29] Using cached data for P15976
# [2025-03-18 16:45:29] Using cached data for P0DPI2
# [2025-03-18 16:45:29] Using cached data for P50440
# [2025-03-18 16:45:29] Processed 400/1257 IDs. Saved results to uniprot_cache/interim_results_400.csv
# [2025-03-18 16:45:29] Using cached data for P04062
# [2025-03-18 16:45:29] Using cached data for Q92538
# [2025-03-18 16:45:29] Using cached data for Q8N5D6
# [2025-03-18 16:45:29] Using cached data for P47871
# [2025-03-18 16:45:29] Using cached data for Q92616
# [2025-03-18 16:45:29] Using cached data for O95390
# [2025-03-18 16:45:29] Using cached data for Q99988
# [2025-03-18 16:45:29] Using cached data for P43026
# [2025-03-18 16:45:29] Using cached data for Q8TEQ6
# [2025-03-18 16:45:29] Using cached data for O43681
# [2025-03-18 16:45:29] Using cached data for O95749
# [2025-03-18 16:45:29] Using cached data for P48165
# [2025-03-18 16:45:29] Using cached data for P23416
# [2025-03-18 16:45:29] Using cached data for P48167
# [2025-03-18 16:45:29] Using cached data for P30679
# [2025-03-18 16:45:29] Using cached data for P63096
# [2025-03-18 16:45:29] Using cached data for P08754
# [2025-03-18 16:45:29] Using cached data for P09471
# [2025-03-18 16:45:29] Using cached data for P62879
# [2025-03-18 16:45:29] Using cached data for Q9Y223
# [2025-03-18 16:45:29] Using cached data for Q96EK6
# [2025-03-18 16:45:29] Using cached data for Q8IV16
# [2025-03-18 16:45:29] Using cached data for O15529
# [2025-03-18 16:45:29] Using cached data for Q6PI77
# [2025-03-18 16:45:29] Using cached data for P42261
# [2025-03-18 16:45:29] Using cached data for P42262
# [2025-03-18 16:45:29] Using cached data for Q13002
# [2025-03-18 16:45:29] Using cached data for Q05586
# [2025-03-18 16:45:29] Using cached data for Q12879
# [2025-03-18 16:45:29] Using cached data for Q13224
# [2025-03-18 16:45:29] Using cached data for Q14831
# [2025-03-18 16:45:29] Using cached data for Q8TAX9
# [2025-03-18 16:45:29] Using cached data for P48637
# [2025-03-18 16:45:29] Using cached data for Q9NYZ3
# [2025-03-18 16:45:29] Using cached data for P02724
# [2025-03-18 16:45:29] Using cached data for Q7Z2G1
# [2025-03-18 16:45:29] Using cached data for P84243
# [2025-03-18 16:45:29] Using cached data for P62805
# [2025-03-18 16:45:29] Using cached data for Q14CZ0
# [2025-03-18 16:45:29] Using cached data for P69891
# [2025-03-18 16:45:29] Using cached data for Q9UL51
# [2025-03-18 16:45:29] Using cached data for Q9Y3Q4
# [2025-03-18 16:45:29] Using cached data for P56524
# [2025-03-18 16:45:29] Using cached data for Q00341
# [2025-03-18 16:45:29] Using cached data for Q7Z4Q2
# [2025-03-18 16:45:29] Using cached data for Q9ULT8
# [2025-03-18 16:45:29] Using cached data for Q9BYK8
# [2025-03-18 16:45:29] Using cached data for P07686
# [2025-03-18 16:45:29] Using cached data for Q5VTY9
# [2025-03-18 16:45:29] Using cached data for P15822
# [2025-03-18 16:45:29] Using cached data for Q5T1R4
# [2025-03-18 16:45:29] Using cached data for P28067
# [2025-03-18 16:45:29] Using cached data for P28068
# [2025-03-18 16:45:29] Using cached data for P08397
# [2025-03-18 16:45:29] Using cached data for P04035
# [2025-03-18 16:45:29] Using cached data for P20823
# [2025-03-18 16:45:29] Using cached data for Q32P51
# [2025-03-18 16:45:29] Using cached data for P22626
# [2025-03-18 16:45:29] Using cached data for P31943
# [2025-03-18 16:45:29] Using cached data for O43390
# [2025-03-18 16:45:29] Using cached data for P49639
# [2025-03-18 16:45:29] Using cached data for P32754
# [2025-03-18 16:45:29] Using cached data for Q96IR7
# [2025-03-18 16:45:29] Using cached data for Q7LGA3
# [2025-03-18 16:45:29] Using cached data for Q7Z5P4
# [2025-03-18 16:45:29] Using cached data for O75031
# [2025-03-18 16:45:29] Using cached data for Q4G112
# [2025-03-18 16:45:29] Using cached data for Q14568
# [2025-03-18 16:45:29] Using cached data for P28335
# [2025-03-18 16:45:29] Using cached data for Q96D96
# [2025-03-18 16:45:29] Using cached data for Q9BYI3
# [2025-03-18 16:45:29] Using cached data for Q9NX55
# [2025-03-18 16:45:29] Using cached data for Q6ZQW0
# [2025-03-18 16:45:29] Using cached data for Q9BYX4
# [2025-03-18 16:45:29] Using cached data for P01563
# [2025-03-18 16:45:29] Using cached data for Q12894
# [2025-03-18 16:45:29] Using cached data for A0AVF1
# [2025-03-18 16:45:29] Using cached data for Q86WT1
# [2025-03-18 16:45:29] Using cached data for Q8N4P2
# [2025-03-18 16:45:29] Using cached data for Q96LB3
# [2025-03-18 16:45:29] Using cached data for P01601
# [2025-03-18 16:45:29] Using cached data for Q96MC9
# [2025-03-18 16:45:29] Using cached data for Q9UKT9
# [2025-03-18 16:45:29] Using cached data for P35225
# [2025-03-18 16:45:29] Using cached data for Q6ZVW7
# [2025-03-18 16:45:29] Using cached data for P14778
# [2025-03-18 16:45:29] Using cached data for Q9NZH6
# [2025-03-18 16:45:29] Using cached data for P08887
# [2025-03-18 16:45:29] Using cached data for P40189
# [2025-03-18 16:45:29] Using cached data for Q96N11
# [2025-03-18 16:45:29] Using cached data for O15397
# [2025-03-18 16:45:29] Using cached data for P17301
# [2025-03-18 16:45:29] Using cached data for P05107
# [2025-03-18 16:45:29] Using cached data for Q14573
# [2025-03-18 16:45:29] Using cached data for P78504
# [2025-03-18 16:45:29] Using cached data for Q9Y219
# [2025-03-18 16:45:29] Using cached data for P23458
# [2025-03-18 16:45:29] Using cached data for Q9H9V9
# [2025-03-18 16:45:29] Using cached data for Q15046
# [2025-03-18 16:45:29] Using cached data for Q8N6L0
# [2025-03-18 16:45:29] Processed 500/1257 IDs. Saved results to uniprot_cache/interim_results_500.csv
# [2025-03-18 16:45:29] Using cached data for Q92993
# [2025-03-18 16:45:29] Using cached data for Q9H7Z6
# [2025-03-18 16:45:29] Using cached data for Q9NVX7
# [2025-03-18 16:45:29] Using cached data for P16389
# [2025-03-18 16:45:29] Using cached data for Q96PR1
# [2025-03-18 16:45:29] Using cached data for Q8NCM2
# [2025-03-18 16:45:29] Using cached data for Q9H252
# [2025-03-18 16:45:29] Using cached data for P78508
# [2025-03-18 16:45:29] Using cached data for Q14654
# [2025-03-18 16:45:29] Using cached data for Q9NPI9
# [2025-03-18 16:45:29] Using cached data for Q9H427
# [2025-03-18 16:45:29] Using cached data for Q96T55
# [2025-03-18 16:45:29] Using cached data for Q96T54
# [2025-03-18 16:45:29] Using cached data for Q7Z418
# [2025-03-18 16:45:29] Using cached data for O14649
# [2025-03-18 16:45:29] Using cached data for Q9NPC2
# [2025-03-18 16:45:29] Using cached data for Q9H2S1
# [2025-03-18 16:45:29] Using cached data for Q6UVM3
# [2025-03-18 16:45:29] Using cached data for A8MYU2
# [2025-03-18 16:45:29] Using cached data for Q8TDN2
# [2025-03-18 16:45:29] Using cached data for Q96SI1
# [2025-03-18 16:45:29] Using cached data for Q8N5Z5
# [2025-03-18 16:45:29] Using cached data for P33947
# [2025-03-18 16:45:29] Using cached data for O94953
# [2025-03-18 16:45:29] Using cached data for Q06136
# [2025-03-18 16:45:29] Using cached data for Q8IZA0
# [2025-03-18 16:45:29] Using cached data for Q96MD2
# [2025-03-18 16:45:29] Using cached data for Q9ULH0
# [2025-03-18 16:45:29] Using cached data for Q12756
# [2025-03-18 16:45:29] Using cached data for O95235
# [2025-03-18 16:45:29] Using cached data for Q7Z4S6
# [2025-03-18 16:45:29] Using cached data for Q02241
# [2025-03-18 16:45:29] Using cached data for Q9Y6Z4
# [2025-03-18 16:45:29] Using cached data for O15066
# [2025-03-18 16:45:29] Using cached data for O14782
# [2025-03-18 16:45:29] Using cached data for P43626
# [2025-03-18 16:45:29] Using cached data for Q96J84
# [2025-03-18 16:45:29] Using cached data for Q6UWL6
# [2025-03-18 16:45:29] Using cached data for Q13351
# [2025-03-18 16:45:29] Using cached data for Q6TFL4
# [2025-03-18 16:45:29] Using cached data for Q9UH77
# [2025-03-18 16:45:29] Using cached data for Q9UBX7
# [2025-03-18 16:45:29] Using cached data for P03952
# [2025-03-18 16:45:29] Using cached data for P26717
# [2025-03-18 16:45:29] Using cached data for P26718
# [2025-03-18 16:45:29] Using cached data for Q9UMN6
# [2025-03-18 16:45:29] Using cached data for O14686
# [2025-03-18 16:45:29] Using cached data for P01042
# [2025-03-18 16:45:29] Using cached data for Q8NG31
# [2025-03-18 16:45:29] Using cached data for Q5T750
# [2025-03-18 16:45:29] Using cached data for O00505
# [2025-03-18 16:45:29] Using cached data for P13645
# [2025-03-18 16:45:29] Using cached data for Q8N816
# [2025-03-18 16:45:29] Using cached data for P13646
# [2025-03-18 16:45:29] Using cached data for P02533
# [2025-03-18 16:45:29] Using cached data for O76011
# [2025-03-18 16:45:29] Using cached data for P13647
# [2025-03-18 16:45:29] Using cached data for Q8IUG1
# [2025-03-18 16:45:29] Using cached data for P60331
# [2025-03-18 16:45:29] Using cached data for P60014
# [2025-03-18 16:45:29] Using cached data for P60412
# [2025-03-18 16:45:29] Using cached data for P60413
# [2025-03-18 16:45:29] Using cached data for P60368
# [2025-03-18 16:45:29] Using cached data for P60369
# [2025-03-18 16:45:29] Using cached data for P60372
# [2025-03-18 16:45:29] Using cached data for P60370
# [2025-03-18 16:45:29] Using cached data for P60371
# [2025-03-18 16:45:29] Using cached data for P60409
# [2025-03-18 16:45:29] Using cached data for P60410
# [2025-03-18 16:45:29] Using cached data for P60411
# [2025-03-18 16:45:29] Using cached data for Q8IUC1
# [2025-03-18 16:45:29] Using cached data for P59991
# [2025-03-18 16:45:29] Using cached data for P60328
# [2025-03-18 16:45:29] Using cached data for Q52LG2
# [2025-03-18 16:45:29] Using cached data for Q3LI77
# [2025-03-18 16:45:29] Using cached data for Q3LI76
# [2025-03-18 16:45:29] Using cached data for Q3LHN2
# [2025-03-18 16:45:29] Using cached data for Q3LI73
# [2025-03-18 16:45:29] Using cached data for Q3LI54
# [2025-03-18 16:45:29] Using cached data for Q3LI61
# [2025-03-18 16:45:29] Using cached data for Q3MIV0
# [2025-03-18 16:45:29] Using cached data for Q3LHN0
# [2025-03-18 16:45:29] Using cached data for Q6PEX3
# [2025-03-18 16:45:29] Using cached data for Q3LI81
# [2025-03-18 16:45:29] Using cached data for Q9BYR0
# [2025-03-18 16:45:29] Using cached data for Q3LI67
# [2025-03-18 16:45:29] Using cached data for Q6GTX8
# [2025-03-18 16:45:29] Using cached data for Q16787
# [2025-03-18 16:45:29] Using cached data for Q16363
# [2025-03-18 16:45:29] Using cached data for O15230
# [2025-03-18 16:45:29] Using cached data for P55268
# [2025-03-18 16:45:29] Using cached data for Q96B96
# [2025-03-18 16:45:29] Using cached data for Q8NC56
# [2025-03-18 16:45:29] Using cached data for Q96BZ8
# [2025-03-18 16:45:29] Using cached data for O95202
# [2025-03-18 16:45:29] Using cached data for Q8NES3
# [2025-03-18 16:45:29] Using cached data for A8MUM7
# [2025-03-18 16:45:29] Using cached data for Q8N145
# [2025-03-18 16:45:29] Using cached data for P18858
# [2025-03-18 16:45:29] Using cached data for P49916
# [2025-03-18 16:45:29] Processed 600/1257 IDs. Saved results to uniprot_cache/interim_results_600.csv
# [2025-03-18 16:45:29] Using cached data for P59901
# [2025-03-18 16:45:29] Using cached data for Q8N423
# [2025-03-18 16:45:29] Using cached data for O75023
# [2025-03-18 16:45:29] Using cached data for Q6XXX2
# [2025-03-18 16:45:29] Using cached data for Q3SY05
# [2025-03-18 16:45:29] Using cached data for Q6ZN03
# [2025-03-18 16:45:29] Using cached data for Q6ZUF6
# [2025-03-18 16:45:29] Using cached data for Q8N8I6
# [2025-03-18 16:45:29] Using cached data for Q8N0U6
# [2025-03-18 16:45:29] Using cached data for Q86TU6
# [2025-03-18 16:45:29] Using cached data for Q96FQ7
# [2025-03-18 16:45:29] Using cached data for Q9H8X3
# [2025-03-18 16:45:29] Using cached data for Q52M75
# [2025-03-18 16:45:29] Using cached data for Q8NAE3
# [2025-03-18 16:45:29] Using cached data for Q5JQF7
# [2025-03-18 16:45:29] Using cached data for Q495D7
# [2025-03-18 16:45:29] Using cached data for Q99440
# [2025-03-18 16:45:29] Using cached data for Q96MT4
# [2025-03-18 16:45:29] Using cached data for Q8NAA6
# [2025-03-18 16:45:29] Using cached data for Q86X59
# [2025-03-18 16:45:29] Using cached data for Q6ZV77
# [2025-03-18 16:45:29] Using cached data for Q52M58
# [2025-03-18 16:45:29] Using cached data for Q8N8G6
# [2025-03-18 16:45:29] Using cached data for Q8N319
# [2025-03-18 16:45:29] Using cached data for Q6ZUL3
# [2025-03-18 16:45:29] Using cached data for Q2M2E5
# [2025-03-18 16:45:29] Using cached data for Q9Y234
# [2025-03-18 16:45:29] Using cached data for Q68DH5
# [2025-03-18 16:45:29] Using cached data for Q96KR4
# [2025-03-18 16:45:29] Using cached data for P20700
# [2025-03-18 16:45:29] Using cached data for Q03252
# [2025-03-18 16:45:29] Using cached data for O60663
# [2025-03-18 16:45:29] Using cached data for P08519
# [2025-03-18 16:45:29] Using cached data for P43657
# [2025-03-18 16:45:29] Using cached data for Q07954
# [2025-03-18 16:45:29] Using cached data for P83369
# [2025-03-18 16:45:29] Using cached data for Q8IV03
# [2025-03-18 16:45:29] Using cached data for Q9NX58
# [2025-03-18 16:45:29] Using cached data for P07948
# [2025-03-18 16:45:29] Using cached data for Q8N6I4
# [2025-03-18 16:45:29] Using cached data for Q8N653
# [2025-03-18 16:45:29] Using cached data for O94854
# [2025-03-18 16:45:29] Using cached data for Q8WXG6
# [2025-03-18 16:45:29] Using cached data for O75444
# [2025-03-18 16:45:29] Using cached data for P43359
# [2025-03-18 16:45:29] Using cached data for P46821
# [2025-03-18 16:45:29] Using cached data for Q02750
# [2025-03-18 16:45:29] Using cached data for Q99558
# [2025-03-18 16:45:29] Using cached data for Q9NYL2
# [2025-03-18 16:45:29] Using cached data for P28482
# [2025-03-18 16:45:29] Using cached data for O60307
# [2025-03-18 16:45:29] Using cached data for P61244
# [2025-03-18 16:45:29] Using cached data for P02144
# [2025-03-18 16:45:29] Using cached data for Q8IYB1
# [2025-03-18 16:45:29] Using cached data for O95243
# [2025-03-18 16:45:29] Using cached data for Q8IVS2
# [2025-03-18 16:45:29] Using cached data for Q99705
# [2025-03-18 16:45:29] Using cached data for Q7L590
# [2025-03-18 16:45:29] Using cached data for O15151
# [2025-03-18 16:45:29] Using cached data for O15553
# [2025-03-18 16:45:29] Using cached data for O00255
# [2025-03-18 16:45:29] Using cached data for P08581
# [2025-03-18 16:45:29] Using cached data for Q8N6R0
# [2025-03-18 16:45:29] Using cached data for Q96FB5
# [2025-03-18 16:45:29] Using cached data for O95140
# [2025-03-18 16:45:29] Using cached data for Q8NA29
# [2025-03-18 16:45:29] Using cached data for O43451
# [2025-03-18 16:45:29] Using cached data for O94851
# [2025-03-18 16:45:29] Using cached data for Q9UNW1
# [2025-03-18 16:45:29] Using cached data for Q5T4H9
# [2025-03-18 16:45:29] Using cached data for Q5VWP3
# [2025-03-18 16:45:29] Using cached data for Q9Y6X9
# [2025-03-18 16:45:29] Using cached data for P00540
# [2025-03-18 16:45:29] Using cached data for Q9BXT6
# [2025-03-18 16:45:29] Using cached data for Q2M385
# [2025-03-18 16:45:29] Using cached data for O00566
# [2025-03-18 16:45:29] Using cached data for O60487
# [2025-03-18 16:45:29] Using cached data for P49959
# [2025-03-18 16:45:29] Using cached data for Q2M3A8
# [2025-03-18 16:45:29] Using cached data for P52815
# [2025-03-18 16:45:29] Using cached data for P82663
# [2025-03-18 16:45:29] Using cached data for Q9Y2Q9
# [2025-03-18 16:45:29] Using cached data for O15457
# [2025-03-18 16:45:29] Using cached data for O94964
# [2025-03-18 16:45:29] Using cached data for P11586
# [2025-03-18 16:45:29] Using cached data for Q9BSJ5
# [2025-03-18 16:45:29] Using cached data for Q9H3J6
# [2025-03-18 16:45:29] Using cached data for Q765P7
# [2025-03-18 16:45:29] Using cached data for Q02817
# [2025-03-18 16:45:29] Using cached data for Q9H195
# [2025-03-18 16:45:29] Using cached data for Q99102
# [2025-03-18 16:45:29] Using cached data for P01106
# [2025-03-18 16:45:29] Using cached data for Q8TBZ2
# [2025-03-18 16:45:29] Using cached data for P04198
# [2025-03-18 16:45:29] Using cached data for Q9HB07
# [2025-03-18 16:45:29] Using cached data for P35749
# [2025-03-18 16:45:29] Using cached data for Q9Y2K3
# [2025-03-18 16:45:29] Using cached data for Q96A32
# [2025-03-18 16:45:29] Using cached data for Q96JP2
# [2025-03-18 16:45:29] Using cached data for Q9Y6X6
# [2025-03-18 16:45:29] Processed 700/1257 IDs. Saved results to uniprot_cache/interim_results_700.csv
# [2025-03-18 16:45:29] Using cached data for Q12965
# [2025-03-18 16:45:29] Using cached data for Q8NEV4
# [2025-03-18 16:45:29] Using cached data for Q9ULV0
# [2025-03-18 16:45:29] Using cached data for P54296
# [2025-03-18 16:45:29] Using cached data for P61599
# [2025-03-18 16:45:29] Using cached data for Q93015
# [2025-03-18 16:45:30] Using cached data for O75949
# [2025-03-18 16:45:30] Using cached data for O43776
# [2025-03-18 16:45:30] Using cached data for P11245
# [2025-03-18 16:45:30] Using cached data for Q8NFP9
# [2025-03-18 16:45:30] Using cached data for Q5TI25
# [2025-03-18 16:45:30] Using cached data for P0C2Y1
# [2025-03-18 16:45:30] Using cached data for Q9UBB6
# [2025-03-18 16:45:30] Using cached data for P55160
# [2025-03-18 16:45:30] Using cached data for O76036
# [2025-03-18 16:45:30] Using cached data for P51970
# [2025-03-18 16:45:30] Using cached data for Q330K2
# [2025-03-18 16:45:30] Using cached data for O96000
# [2025-03-18 16:45:30] Using cached data for O95298
# [2025-03-18 16:45:30] Using cached data for O75306
# [2025-03-18 16:45:30] Using cached data for Q8NBR9
# [2025-03-18 16:45:30] Using cached data for P20929
# [2025-03-18 16:45:30] Using cached data for P12036
# [2025-03-18 16:45:30] Using cached data for Q86SG6
# [2025-03-18 16:45:30] Using cached data for Q9UBC1
# [2025-03-18 16:45:30] Using cached data for Q9Y697
# [2025-03-18 16:45:30] Using cached data for Q9UMS0
# [2025-03-18 16:45:30] Using cached data for O14745
# [2025-03-18 16:45:30] Using cached data for Q9P206
# [2025-03-18 16:45:30] Using cached data for Q0D2K0
# [2025-03-18 16:45:30] Using cached data for Q9UFN0
# [2025-03-18 16:45:30] Using cached data for Q9BS92
# [2025-03-18 16:45:30] Using cached data for Q9HC29
# [2025-03-18 16:45:30] Using cached data for Q9NPE3
# [2025-03-18 16:45:30] Using cached data for Q8N5I9
# [2025-03-18 16:45:30] Using cached data for O75052
# [2025-03-18 16:45:30] Using cached data for Q7Z3S9
# [2025-03-18 16:45:30] Using cached data for Q9NP85
# [2025-03-18 16:45:30] Using cached data for P17342
# [2025-03-18 16:45:30] Using cached data for Q15818
# [2025-03-18 16:45:30] Using cached data for Q9HCQ7
# [2025-03-18 16:45:30] Using cached data for P50391
# [2025-03-18 16:45:30] Using cached data for Q14995
# [2025-03-18 16:45:30] Using cached data for P43354
# [2025-03-18 16:45:30] Using cached data for O96028
# [2025-03-18 16:45:30] Using cached data for P46459
# [2025-03-18 16:45:30] Using cached data for Q8TEA1
# [2025-03-18 16:45:30] Using cached data for Q86YG4
# [2025-03-18 16:45:30] Using cached data for P78549
# [2025-03-18 16:45:30] Using cached data for Q5VVY1
# [2025-03-18 16:45:30] Using cached data for P36639
# [2025-03-18 16:45:30] Using cached data for Q9GZU5
# [2025-03-18 16:45:30] Using cached data for P00973
# [2025-03-18 16:45:30] Using cached data for Q96M63
# [2025-03-18 16:45:30] Using cached data for O75665
# [2025-03-18 16:45:30] Using cached data for Q9ULD0
# [2025-03-18 16:45:30] Using cached data for O14841
# [2025-03-18 16:45:30] Using cached data for P04000
# [2025-03-18 16:45:30] Using cached data for P03999
# [2025-03-18 16:45:30] Using cached data for Q8NGC3
# [2025-03-18 16:45:30] Using cached data for Q8NGR6
# [2025-03-18 16:45:30] Using cached data for Q8NGR9
# [2025-03-18 16:45:30] Using cached data for Q8NH41
# [2025-03-18 16:45:30] Using cached data for Q8TCB6
# [2025-03-18 16:45:30] Using cached data for Q8NGJ2
# [2025-03-18 16:45:30] Using cached data for Q8NGH7
# [2025-03-18 16:45:30] Using cached data for Q8NGV7
# [2025-03-18 16:45:30] Using cached data for Q8NGC5
# [2025-03-18 16:45:30] Using cached data for Q6UXT6
# [2025-03-18 16:45:30] Using cached data for P02763
# [2025-03-18 16:45:30] Using cached data for Q6ZRI0
# [2025-03-18 16:45:30] Using cached data for Q3ZCN5
# [2025-03-18 16:45:30] Using cached data for Q96G74
# [2025-03-18 16:45:30] Using cached data for Q96BN8
# [2025-03-18 16:45:30] Using cached data for Q7RTY7
# [2025-03-18 16:45:30] Using cached data for Q15070
# [2025-03-18 16:45:30] Using cached data for Q8TDS5
# [2025-03-18 16:45:30] Using cached data for Q96P68
# [2025-03-18 16:45:30] Using cached data for Q13177
# [2025-03-18 16:45:30] Using cached data for Q8N910
# [2025-03-18 16:45:30] Using cached data for Q9Y2D5
# [2025-03-18 16:45:30] Using cached data for Q9BXP8
# [2025-03-18 16:45:30] Using cached data for Q9NRJ7
# [2025-03-18 16:45:30] Using cached data for Q9Y5E4
# [2025-03-18 16:45:30] Using cached data for Q9Y5E3
# [2025-03-18 16:45:30] Using cached data for Q9Y5E1
# [2025-03-18 16:45:30] Using cached data for P49585
# [2025-03-18 16:45:30] Using cached data for Q9Y233
# [2025-03-18 16:45:30] Using cached data for Q96FX8
# [2025-03-18 16:45:30] Using cached data for O43933
# [2025-03-18 16:45:30] Using cached data for O60683
# [2025-03-18 16:45:30] Using cached data for Q92968
# [2025-03-18 16:45:30] Using cached data for P28328
# [2025-03-18 16:45:30] Using cached data for Q7Z412
# [2025-03-18 16:45:30] Using cached data for P50542
# [2025-03-18 16:45:30] Using cached data for Q9UHJ9
# [2025-03-18 16:45:30] Using cached data for P15735
# [2025-03-18 16:45:30] Using cached data for P42356
# [2025-03-18 16:45:30] Using cached data for Q9UBF8
# [2025-03-18 16:45:30] Using cached data for Q9HB75
# [2025-03-18 16:45:30] Processed 800/1257 IDs. Saved results to uniprot_cache/interim_results_800.csv
# [2025-03-18 16:45:30] Using cached data for Q92508
# [2025-03-18 16:45:30] Using cached data for P37287
# [2025-03-18 16:45:30] Using cached data for Q07326
# [2025-03-18 16:45:30] Using cached data for Q5H8A4
# [2025-03-18 16:45:30] Using cached data for Q969N2
# [2025-03-18 16:45:30] Using cached data for O75747
# [2025-03-18 16:45:30] Using cached data for P48736
# [2025-03-18 16:45:30] Using cached data for Q9BXM7
# [2025-03-18 16:45:30] Using cached data for Q9UG56
# [2025-03-18 16:45:30] Using cached data for Q5JRX3
# [2025-03-18 16:45:30] Using cached data for Q0ZLH3
# [2025-03-18 16:45:30] Using cached data for Q9H7B7
# [2025-03-18 16:45:30] Using cached data for P00749
# [2025-03-18 16:45:30] Using cached data for Q01970
# [2025-03-18 16:45:30] Using cached data for Q15147
# [2025-03-18 16:45:30] Using cached data for Q9P212
# [2025-03-18 16:45:30] Using cached data for P19174
# [2025-03-18 16:45:30] Using cached data for Q96PX9
# [2025-03-18 16:45:30] Using cached data for Q6ZR37
# [2025-03-18 16:45:30] Using cached data for P00747
# [2025-03-18 16:45:30] Using cached data for Q96Q06
# [2025-03-18 16:45:30] Using cached data for Q7Z2D5
# [2025-03-18 16:45:30] Using cached data for P13797
# [2025-03-18 16:45:30] Using cached data for Q9UIW2
# [2025-03-18 16:45:30] Using cached data for P51805
# [2025-03-18 16:45:30] Using cached data for Q9Y4D7
# [2025-03-18 16:45:30] Using cached data for P54278
# [2025-03-18 16:45:30] Using cached data for Q8NA58
# [2025-03-18 16:45:30] Using cached data for P06746
# [2025-03-18 16:45:30] Using cached data for P28340
# [2025-03-18 16:45:30] Using cached data for P54098
# [2025-03-18 16:45:30] Using cached data for Q9UHN1
# [2025-03-18 16:45:30] Using cached data for Q9Y253
# [2025-03-18 16:45:30] Using cached data for O95602
# [2025-03-18 16:45:30] Using cached data for Q9H9Y6
# [2025-03-18 16:45:30] Using cached data for Q9NW08
# [2025-03-18 16:45:30] Using cached data for Q9Y2Y1
# [2025-03-18 16:45:30] Using cached data for O00411
# [2025-03-18 16:45:30] Using cached data for Q8N7R1
# [2025-03-18 16:45:30] Using cached data for Q8NE79
# [2025-03-18 16:45:30] Using cached data for Q9NUX5
# [2025-03-18 16:45:30] Using cached data for Q01851
# [2025-03-18 16:45:30] Using cached data for Q9Y3C6
# [2025-03-18 16:45:30] Using cached data for Q8N3J5
# [2025-03-18 16:45:30] Using cached data for Q5SWA1
# [2025-03-18 16:45:30] Using cached data for Q13522
# [2025-03-18 16:45:30] Using cached data for P30153
# [2025-03-18 16:45:30] Using cached data for P02812
# [2025-03-18 16:45:30] Using cached data for Q04118
# [2025-03-18 16:45:30] Using cached data for Q9NQV6
# [2025-03-18 16:45:30] Using cached data for P57071
# [2025-03-18 16:45:30] Using cached data for P30048
# [2025-03-18 16:45:30] Using cached data for P02810
# [2025-03-18 16:45:30] Using cached data for O43900
# [2025-03-18 16:45:30] Using cached data for P49642
# [2025-03-18 16:45:30] Using cached data for P17612
# [2025-03-18 16:45:30] Using cached data for P22694
# [2025-03-18 16:45:30] Using cached data for P31321
# [2025-03-18 16:45:30] Using cached data for Q9NNZ6
# [2025-03-18 16:45:30] Using cached data for O43272
# [2025-03-18 16:45:30] Using cached data for Q9UF12
# [2025-03-18 16:45:30] Using cached data for O15091
# [2025-03-18 16:45:30] Using cached data for Q13523
# [2025-03-18 16:45:30] Using cached data for P23942
# [2025-03-18 16:45:30] Using cached data for Q9ULL5
# [2025-03-18 16:45:30] Using cached data for P07602
# [2025-03-18 16:45:30] Using cached data for Q9Y617
# [2025-03-18 16:45:30] Using cached data for P11801
# [2025-03-18 16:45:30] Using cached data for P40306
# [2025-03-18 16:45:30] Using cached data for P28065
# [2025-03-18 16:45:30] Using cached data for P78330
# [2025-03-18 16:45:30] Using cached data for Q96NR3
# [2025-03-18 16:45:30] Using cached data for Q6ISU1
# [2025-03-18 16:45:30] Using cached data for Q8N4Q0
# [2025-03-18 16:45:30] Using cached data for Q15257
# [2025-03-18 16:45:30] Using cached data for Q6WKZ4
# [2025-03-18 16:45:30] Using cached data for Q7L804
# [2025-03-18 16:45:30] Using cached data for Q9BZG1
# [2025-03-18 16:45:30] Using cached data for O95755
# [2025-03-18 16:45:30] Using cached data for Q15042
# [2025-03-18 16:45:30] Using cached data for Q9H2M9
# [2025-03-18 16:45:30] Using cached data for P15153
# [2025-03-18 16:45:30] Using cached data for Q9H0H5
# [2025-03-18 16:45:30] Using cached data for Q06609
# [2025-03-18 16:45:30] Using cached data for P11233
# [2025-03-18 16:45:30] Using cached data for P61224
# [2025-03-18 16:45:30] Using cached data for Q96IS3
# [2025-03-18 16:45:30] Using cached data for Q5T481
# [2025-03-18 16:45:30] Using cached data for Q6ZP01
# [2025-03-18 16:45:30] Using cached data for Q9H1K0
# [2025-03-18 16:45:30] Using cached data for Q96I51
# [2025-03-18 16:45:30] Using cached data for Q0VG73
# [2025-03-18 16:45:30] Using cached data for P46063
# [2025-03-18 16:45:30] Using cached data for Q86WS4
# [2025-03-18 16:45:30] Using cached data for P07949
# [2025-03-18 16:45:30] Using cached data for Q2KHR2
# [2025-03-18 16:45:30] Using cached data for Q3MIN7
# [2025-03-18 16:45:30] Using cached data for Q96B86
# [2025-03-18 16:45:30] Using cached data for Q6PJF5
# [2025-03-18 16:45:30] Using cached data for P18577
# [2025-03-18 16:45:30] Processed 900/1257 IDs. Saved results to uniprot_cache/interim_results_900.csv
# [2025-03-18 16:45:30] Using cached data for Q02161
# [2025-03-18 16:45:30] Using cached data for O00212
# [2025-03-18 16:45:30] Using cached data for P84095
# [2025-03-18 16:45:30] Using cached data for O95786
# [2025-03-18 16:45:30] Using cached data for A6NDU8
# [2025-03-18 16:45:30] Using cached data for Q8N999
# [2025-03-18 16:45:30] Using cached data for Q96K19
# [2025-03-18 16:45:30] Using cached data for Q99496
# [2025-03-18 16:45:30] Using cached data for Q5VTB9
# [2025-03-18 16:45:30] Using cached data for Q96EP0
# [2025-03-18 16:45:30] Using cached data for P13489
# [2025-03-18 16:45:30] Using cached data for Q9Y6N7
# [2025-03-18 16:45:30] Using cached data for P27694
# [2025-03-18 16:45:30] Using cached data for P27635
# [2025-03-18 16:45:30] Using cached data for Q96L21
# [2025-03-18 16:45:30] Using cached data for Q9HB90
# [2025-03-18 16:45:30] Using cached data for Q9NQL2
# [2025-03-18 16:45:30] Using cached data for Q7LG56
# [2025-03-18 16:45:30] Using cached data for Q9Y3A4
# [2025-03-18 16:45:30] Using cached data for Q66K80
# [2025-03-18 16:45:30] Using cached data for P21817
# [2025-03-18 16:45:30] Using cached data for Q92736
# ...
# [2025-03-18 16:45:30] Using cached data for P20848
# [2025-03-18 16:45:30] Using cached data for P48595
# [2025-03-18 16:45:30] Using cached data for Q96P15
# [2025-03-18 16:45:30] Using cached data for Q96P63
# [2025-03-18 16:45:30] Using cached data for Q9UIV8
# [2025-03-18 16:45:30] Using cached data for P01008
# [2025-03-18 16:45:30] Using cached data for O15047
# [2025-03-18 16:45:30] Using cached data for Q9UPS6
# [2025-03-18 16:45:30] Using cached data for Q9BYW2
# [2025-03-18 16:45:30] Using cached data for Q8IWL2
# [2025-03-18 16:45:30] Using cached data for Q8IWL1
# [2025-03-18 16:45:30] Using cached data for P11686
# [2025-03-18 16:45:30] Using cached data for P34897
# [2025-03-18 16:45:30] Using cached data for Q9UHJ6
# [2025-03-18 16:45:30] Using cached data for Q6PI26
# [2025-03-18 16:45:30] Using cached data for Q8IUQ4
# [2025-03-18 16:45:30] Using cached data for Q8N6T7
# [2025-03-18 16:45:30] Using cached data for Q15477
# [2025-03-18 16:45:30] Using cached data for Q6PGP7
# [2025-03-18 16:45:30] Using cached data for Q14973
# [2025-03-18 16:45:30] Using cached data for P55011
# [2025-03-18 16:45:30] Using cached data for P55017
# [2025-03-18 16:45:30] Using cached data for Q9UHW9
# [2025-03-18 16:45:30] Using cached data for Q86YT5
# [2025-03-18 16:45:30] Using cached data for Q9NRA2
# [2025-03-18 16:45:30] Using cached data for P54219
# [2025-03-18 16:45:30] Using cached data for P41440
# [2025-03-18 16:45:30] Using cached data for Q53S99
# [2025-03-18 16:45:30] Using cached data for Q9Y226
# [2025-03-18 16:45:30] Using cached data for Q8N1D0
# [2025-03-18 16:45:30] Using cached data for A6NK97
# [2025-03-18 16:45:30] Using cached data for Q9UHI7
# [2025-03-18 16:45:30] Using cached data for Q9Y619
# [2025-03-18 16:45:30] Using cached data for Q9HC21
# [2025-03-18 16:45:30] Using cached data for Q9H2D1
# [2025-03-18 16:45:30] Using cached data for Q96AG3
# [2025-03-18 16:45:30] Using cached data for Q9H2B4
# [2025-03-18 16:45:30] Using cached data for Q8NG04
# [2025-03-18 16:45:30] Using cached data for Q9NRM0
# [2025-03-18 16:45:30] Using cached data for Q9H598
# [2025-03-18 16:45:30] Using cached data for P78382
# [2025-03-18 16:45:30] Using cached data for P78381
# [2025-03-18 16:45:30] Using cached data for Q9Y2D2
# [2025-03-18 16:45:30] Using cached data for Q9NTN3
# [2025-03-18 16:45:30] Using cached data for Q99624
# [2025-03-18 16:45:30] Using cached data for Q92504
# [2025-03-18 16:45:30] Using cached data for Q8IVJ1
# [2025-03-18 16:45:30] Using cached data for Q9Y2W3
# [2025-03-18 16:45:30] Using cached data for Q96NT5
# [2025-03-18 16:45:30] Processed 1000/1257 IDs. Saved results to uniprot_cache/interim_results_1000.csv
# [2025-03-18 16:45:30] Using cached data for Q96FL8
# [2025-03-18 16:45:30] Using cached data for P02730
# [2025-03-18 16:45:30] Using cached data for Q6U841
# [2025-03-18 16:45:30] Using cached data for Q8NBS3
# [2025-03-18 16:45:30] Using cached data for Q9BWU0
# [2025-03-18 16:45:30] Using cached data for P48751
# [2025-03-18 16:45:30] Using cached data for P13866
# [2025-03-18 16:45:30] Using cached data for P53794
# [2025-03-18 16:45:30] Using cached data for Q9Y289
# [2025-03-18 16:45:30] Using cached data for A1A4F0
# [2025-03-18 16:45:30] Using cached data for Q9Y345
# [2025-03-18 16:45:30] Using cached data for Q96CW6
# [2025-03-18 16:45:30] Using cached data for Q9UHI5
# [2025-03-18 16:45:30] Using cached data for Q92581
# [2025-03-18 16:45:30] Using cached data for Q92959
# [2025-03-18 16:45:30] Using cached data for O94956
# [2025-03-18 16:45:30] Using cached data for Q8IX21
# [2025-03-18 16:45:30] Using cached data for Q8N769
# [2025-03-18 16:45:30] Using cached data for Q9H156
# [2025-03-18 16:45:30] Using cached data for Q9NSI2
# [2025-03-18 16:45:30] Using cached data for Q15796
# [2025-03-18 16:45:30] Using cached data for Q9Y6J3
# [2025-03-18 16:45:30] Using cached data for P51531
# [2025-03-18 16:45:30] Using cached data for P51532
# [2025-03-18 16:45:30] Using cached data for Q92922
# [2025-03-18 16:45:30] Using cached data for Q8NDV3
# [2025-03-18 16:45:30] Using cached data for Q8IY18
# [2025-03-18 16:45:30] Using cached data for Q8ND04
# [2025-03-18 16:45:30] Using cached data for P58511
# [2025-03-18 16:45:30] Using cached data for Q96H20
# [2025-03-18 16:45:30] Using cached data for O95149
# [2025-03-18 16:45:30] Using cached data for O15524
# [2025-03-18 16:45:30] Using cached data for P00441
# [2025-03-18 16:45:30] Using cached data for Q2M3V2
# [2025-03-18 16:45:30] Using cached data for P35716
# [2025-03-18 16:45:30] Using cached data for Q3SY56
# [2025-03-18 16:45:30] Using cached data for Q5MJ09
# [2025-03-18 16:45:30] Using cached data for Q6ZUB1
# [2025-03-18 16:45:30] Using cached data for Q63HN1
# [2025-03-18 16:45:30] Using cached data for Q5VYM1
# [2025-03-18 16:45:30] Using cached data for Q68DN1
# [2025-03-18 16:45:30] Using cached data for A6NFR6
# [2025-03-18 16:45:30] Using cached data for Q69YQ0
# [2025-03-18 16:45:30] Using cached data for P17947
# [2025-03-18 16:45:30] Using cached data for O43291
# [2025-03-18 16:45:30] Using cached data for A8MV24
# [2025-03-18 16:45:30] Using cached data for Q9P2T0
# [2025-03-18 16:45:30] Using cached data for Q96LM5
# [2025-03-18 16:45:30] Using cached data for Q8N865
# [2025-03-18 16:45:30] Using cached data for Q8WW14
# [2025-03-18 16:45:30] Using cached data for Q8NCR6
# [2025-03-18 16:45:30] Using cached data for Q6URK8
# [2025-03-18 16:45:30] Using cached data for Q96LM6
# [2025-03-18 16:45:30] Using cached data for Q9BUD6
# [2025-03-18 16:45:30] Using cached data for Q7Z698
# [2025-03-18 16:45:30] Using cached data for Q8WW59
# [2025-03-18 16:45:30] Using cached data for Q13813
# [2025-03-18 16:45:30] Using cached data for Q01082
# [2025-03-18 16:45:30] Using cached data for O15269
# [2025-03-18 16:45:30] Using cached data for Q969W0
# [2025-03-18 16:45:30] Using cached data for Q9Y6N5
# [2025-03-18 16:45:30] Using cached data for Q9HD15
# [2025-03-18 16:45:30] Using cached data for P31213
# [2025-03-18 16:45:30] Using cached data for P36956
# [2025-03-18 16:45:30] Using cached data for Q07955
# [2025-03-18 16:45:30] Using cached data for Q04837
# [2025-03-18 16:45:30] Using cached data for Q9Y2M2
# [2025-03-18 16:45:30] Using cached data for Q9NSC7
# [2025-03-18 16:45:30] Using cached data for Q8NDV1
# [2025-03-18 16:45:30] Using cached data for Q9UJ98
# [2025-03-18 16:45:30] Using cached data for P52630
# [2025-03-18 16:45:30] Using cached data for P40763
# [2025-03-18 16:45:30] Using cached data for Q14765
# [2025-03-18 16:45:30] Using cached data for P51692
# [2025-03-18 16:45:30] Using cached data for P42226
# [2025-03-18 16:45:30] Using cached data for P49842
# [2025-03-18 16:45:30] Using cached data for P46977
# [2025-03-18 16:45:30] Using cached data for Q13190
# [2025-03-18 16:45:30] Using cached data for Q9HAC7
# [2025-03-18 16:45:30] Using cached data for O43704
# [2025-03-18 16:45:30] Using cached data for Q6EEV6
# [2025-03-18 16:45:30] Using cached data for O94901
# [2025-03-18 16:45:30] Using cached data for Q15527
# [2025-03-18 16:45:30] Using cached data for P43405
# [2025-03-18 16:45:30] Using cached data for P17600
# [2025-03-18 16:45:30] Using cached data for O15061
# [2025-03-18 16:45:30] Using cached data for Q8N9I0
# [2025-03-18 16:45:30] Using cached data for Q8NBV8
# [2025-03-18 16:45:30] Using cached data for P21675
# [2025-03-18 16:45:30] Using cached data for Q16635
# [2025-03-18 16:45:30] Using cached data for P37837
# [2025-03-18 16:45:30] Using cached data for Q6ICL3
# [2025-03-18 16:45:30] Using cached data for Q7L7X3
# [2025-03-18 16:45:30] Using cached data for Q03518
# [2025-03-18 16:45:30] Using cached data for O15533
# [2025-03-18 16:45:30] Using cached data for B6A8C7
# [2025-03-18 16:45:30] Using cached data for Q7RTR8
# [2025-03-18 16:45:30] Using cached data for Q9H6P5
# [2025-03-18 16:45:30] Using cached data for Q9HA65
# [2025-03-18 16:45:30] Using cached data for Q9UHD2
# [2025-03-18 16:45:30] Processed 1100/1257 IDs. Saved results to uniprot_cache/interim_results_1100.csv
# [2025-03-18 16:45:30] Using cached data for Q15170
# [2025-03-18 16:45:30] Using cached data for Q96QE5
# [2025-03-18 16:45:30] Using cached data for A6NCJ1
# [2025-03-18 16:45:30] Using cached data for Q8IYK2
# [2025-03-18 16:45:30] Using cached data for Q5XG87
# [2025-03-18 16:45:30] Using cached data for O14746
# [2025-03-18 16:45:30] Using cached data for Q6N021
# [2025-03-18 16:45:30] Using cached data for P19532
# [2025-03-18 16:45:30] Using cached data for P01137
# [2025-03-18 16:45:30] Using cached data for Q96EK4
# [2025-03-18 16:45:30] Using cached data for P35442
# [2025-03-18 16:45:30] Using cached data for Q96FV9
# [2025-03-18 16:45:30] Using cached data for Q8NI27
# [2025-03-18 16:45:30] Using cached data for P40225
# [2025-03-18 16:45:30] Using cached data for Q9NXG2
# [2025-03-18 16:45:30] Using cached data for P31483
# [2025-03-18 16:45:30] Using cached data for P51854
# [2025-03-18 16:45:30] Using cached data for Q86UE8
# [2025-03-18 16:45:30] Using cached data for Q9NYK1
# [2025-03-18 16:45:30] Using cached data for Q9NR97
# [2025-03-18 16:45:30] Using cached data for Q9BRN9
# [2025-03-18 16:45:30] Using cached data for Q9H061
# [2025-03-18 16:45:30] Using cached data for Q9BVK8
# [2025-03-18 16:45:30] Using cached data for Q8N4L1
# [2025-03-18 16:45:30] Using cached data for Q8TC26
# [2025-03-18 16:45:30] Using cached data for Q9HC07
# [2025-03-18 16:45:30] Using cached data for Q1AE95
# [2025-03-18 16:45:30] Using cached data for Q8NFB2
# [2025-03-18 16:45:30] Using cached data for A2RU14
# [2025-03-18 16:45:30] Using cached data for Q9H0R3
# [2025-03-18 16:45:30] Using cached data for Q6GV28
# [2025-03-18 16:45:30] Using cached data for Q9NX78
# [2025-03-18 16:45:30] Using cached data for Q5HYA8
# [2025-03-18 16:45:30] Using cached data for Q6ZMR5
# [2025-03-18 16:45:30] Using cached data for Q86T26
# [2025-03-18 16:45:30] Using cached data for Q9UL52
# [2025-03-18 16:45:30] Using cached data for Q6ZWK6
# [2025-03-18 16:45:30] Using cached data for O15393
# [2025-03-18 16:45:30] Using cached data for Q9H8H3
# [2025-03-18 16:45:30] Using cached data for Q96JJ7
# [2025-03-18 16:45:30] Using cached data for Q8WVP5
# [2025-03-18 16:45:30] Using cached data for Q5GJ75
# [2025-03-18 16:45:30] Using cached data for O00220
# [2025-03-18 16:45:30] Using cached data for O14763
# [2025-03-18 16:45:30] Using cached data for O14798
# [2025-03-18 16:45:30] Using cached data for Q9UBN6
# [2025-03-18 16:45:30] Using cached data for Q9Y6Q6
# [2025-03-18 16:45:30] Using cached data for O00300
# [2025-03-18 16:45:30] Using cached data for O14836
# [2025-03-18 16:45:30] Using cached data for Q96RJ3
# [2025-03-18 16:45:30] Using cached data for P63316
# [2025-03-18 16:45:30] Using cached data for P02585
# [2025-03-18 16:45:30] Using cached data for Q59H18
# [2025-03-18 16:45:30] Using cached data for P13805
# [2025-03-18 16:45:30] Using cached data for O14787
# [2025-03-18 16:45:30] Using cached data for Q92752
# [2025-03-18 16:45:30] Using cached data for Q9HCJ0
# [2025-03-18 16:45:30] Using cached data for Q9HBL0
# [2025-03-18 16:45:30] Using cached data for Q9Y4F4
# [2025-03-18 16:45:30] Using cached data for O60784
# [2025-03-18 16:45:30] Using cached data for Q9P0U1
# [2025-03-18 16:45:30] Using cached data for Q8WZ04
# [2025-03-18 16:45:30] Using cached data for Q02880
# [2025-03-18 16:45:30] Using cached data for O14656
# [2025-03-18 16:45:30] Using cached data for Q9H3D4
# [2025-03-18 16:45:30] Using cached data for Q8IWU9
# [2025-03-18 16:45:30] Using cached data for P29144
# [2025-03-18 16:45:30] Using cached data for P20231
# [2025-03-18 16:45:30] Using cached data for Q9NRR2
# [2025-03-18 16:45:30] Using cached data for Q9NZC2
# [2025-03-18 16:45:30] Using cached data for Q86XT4
# [2025-03-18 16:45:30] Using cached data for Q15645
# [2025-03-18 16:45:30] Using cached data for Q32P41
# [2025-03-18 16:45:30] Using cached data for Q96Q11
# [2025-03-18 16:45:30] Using cached data for Q13507
# [2025-03-18 16:45:30] Using cached data for Q9HCF6
# [2025-03-18 16:45:30] Using cached data for Q9BX84
# [2025-03-18 16:45:30] Using cached data for Q96QT4
# [2025-03-18 16:45:30] Using cached data for Q9NQA5
# [2025-03-18 16:45:30] Using cached data for P01222
# [2025-03-18 16:45:30] Using cached data for P16473
# [2025-03-18 16:45:30] Using cached data for O95153
# [2025-03-18 16:45:30] Using cached data for O43156
# [2025-03-18 16:45:30] Using cached data for A6NNM8
# [2025-03-18 16:45:30] Using cached data for Q8N841
# [2025-03-18 16:45:30] Using cached data for Q3ZCM7
# [2025-03-18 16:45:30] Using cached data for P49411
# [2025-03-18 16:45:30] Using cached data for O75386
# [2025-03-18 16:45:30] Using cached data for Q2TAM9
# [2025-03-18 16:45:30] Using cached data for P26368
# [2025-03-18 16:45:30] Using cached data for P22314
# [2025-03-18 16:45:30] Using cached data for Q9UBT2
# [2025-03-18 16:45:30] Using cached data for P49459
# [2025-03-18 16:45:30] Using cached data for Q7Z3V4
# [2025-03-18 16:45:30] Using cached data for Q6NVU6
# [2025-03-18 16:45:30] Using cached data for Q9NUQ7
# [2025-03-18 16:45:30] Using cached data for Q8N2C9
# [2025-03-18 16:45:30] Using cached data for Q8IWX7
# [2025-03-18 16:45:30] Using cached data for Q69YU5
# [2025-03-18 16:45:30] Using cached data for P31930
# [2025-03-18 16:45:30] Processed 1200/1257 IDs. Saved results to uniprot_cache/interim_results_1200.csv
# [2025-03-18 16:45:30] Using cached data for Q70EK8
# [2025-03-18 16:45:30] Using cached data for Q93009
# [2025-03-18 16:45:30] Using cached data for Q93008
# [2025-03-18 16:45:30] Using cached data for Q68CQ4
# [2025-03-18 16:45:30] Using cached data for Q5XKR9
# [2025-03-18 16:45:30] Using cached data for Q14135
# [2025-03-18 16:45:30] Using cached data for Q7Z5H5
# [2025-03-18 16:45:30] Using cached data for Q96RL7
# [2025-03-18 16:45:30] Using cached data for Q9H267
# [2025-03-18 16:45:30] Using cached data for Q7Z3J2
# [2025-03-18 16:45:30] Using cached data for P49754
# [2025-03-18 16:45:30] Using cached data for Q9UN37
# [2025-03-18 16:45:30] Using cached data for Q99986
# [2025-03-18 16:45:30] Using cached data for A3KMH1
# [2025-03-18 16:45:30] Using cached data for P23381
# [2025-03-18 16:45:30] Using cached data for Q9UGM6
# [2025-03-18 16:45:30] Using cached data for O75083
# [2025-03-18 16:45:30] Using cached data for Q9H1Z4
# [2025-03-18 16:45:30] Using cached data for Q9Y2I8
# [2025-03-18 16:45:30] Using cached data for Q14508
# [2025-03-18 16:45:30] Using cached data for Q5T9L3
# [2025-03-18 16:45:30] Using cached data for Q9BYP7
# [2025-03-18 16:45:30] Using cached data for Q9ULE0
# [2025-03-18 16:45:30] Using cached data for Q9UBH6
# [2025-03-18 16:45:30] Using cached data for P18887
# [2025-03-18 16:45:30] Using cached data for O43543
# [2025-03-18 16:45:30] Using cached data for Q13426
# [2025-03-18 16:45:30] Using cached data for P54577
# [2025-03-18 16:45:30] Using cached data for Q5BJH7
# [2025-03-18 16:45:30] Using cached data for Q969M3
# [2025-03-18 16:45:30] Using cached data for Q8N8F6
# [2025-03-18 16:45:30] Using cached data for P13994
# [2025-03-18 16:45:30] Using cached data for Q86U90
# [2025-03-18 16:45:30] Using cached data for Q9Y442
# [2025-03-18 16:45:30] Using cached data for O95365
# [2025-03-18 16:45:30] Using cached data for Q96BR9
# [2025-03-18 16:45:30] Using cached data for P17010
# [2025-03-18 16:45:30] Using cached data for Q96K21
# [2025-03-18 16:45:30] Using cached data for Q68DK2
# [2025-03-18 16:45:30] Using cached data for O60844
# [2025-03-18 16:45:30] Using cached data for Q96DA0
# [2025-03-18 16:45:30] Using cached data for Q96T25
# [2025-03-18 16:45:30] Using cached data for Q9UBW7
# [2025-03-18 16:45:30] Using cached data for Q14202
# [2025-03-18 16:45:30] Using cached data for Q9UJW8
# [2025-03-18 16:45:30] Using cached data for Q5T742
# [2025-03-18 16:45:30] Using cached data for Q9UJW7
# [2025-03-18 16:45:30] Using cached data for P59817
# [2025-03-18 16:45:30] Using cached data for Q86YH2
# [2025-03-18 16:45:30] Using cached data for Q96NJ3
# [2025-03-18 16:45:30] Using cached data for Q9C0G0
# [2025-03-18 16:45:30] Using cached data for Q96JG9
# [2025-03-18 16:45:30] Using cached data for Q96K58
# [2025-03-18 16:45:30] Using cached data for P17019
# [2025-03-18 16:45:30] Using cached data for O60290
# [2025-03-18 16:45:30] Using cached data for Q9BRT8
# [2025-03-18 16:45:30] Using cached data for Q5RIA9
# [2025-03-18 16:45:30] Final results saved to uniprot_cache/final_results.csv

# %%
mane_results
# Out:
#      Swiss-Prot AC      MANE-Select ID       Ensembl ID         Protein ID  \
# 0           P49588  ENST00000261772.13  ENST00000261772  ENSP00000261772.8
# 1           P78363   ENST00000370225.4  ENST00000370225  ENSP00000359245.3
# 2           Q9NP58   ENST00000265316.9  ENST00000265316  ENSP00000265316.3
# 3           O14678   ENST00000356924.9  ENST00000356924  ENSP00000349396.4
# 4           Q96SE0   ENST00000316470.9  ENST00000316470  ENSP00000326491.4
# ...            ...                 ...              ...                ...
# 1252        Q96K58   ENST00000300849.5  ENST00000300849  ENSP00000300849.4
# 1253        P17019   ENST00000356929.3  ENST00000356929  ENSP00000349401.2
# 1254        O60290   ENST00000223210.5  ENST00000223210  ENSP00000223210.4
# 1255        Q9BRT8   ENST00000356521.9  ENST00000356521  ENSP00000348915.4
# 1256        Q5RIA9   ENST00000382405.8  ENST00000382405  ENSP00000371842.3
#
#      RefSeq Nucleotide ID RefSeq Protein ID Error
# 0             NM_001605.3       NP_001596.2  None
# 1             NM_000350.3       NP_000341.2  None
# 2             NM_005689.4       NP_005680.1  None
# 3             NM_005050.4       NP_005041.1  None
# 4             NM_032604.4       NP_115993.3  None
# ...                   ...               ...   ...
# 1252          NM_024706.5       NP_078982.3  None
# 1253          NM_021269.3       NP_067092.2  None
# 1254       NM_001099220.3    NP_001092690.1  None
# 1255          NM_018491.5       NP_060961.3  None
# 1256       NM_001330668.2    NP_001317597.1  None
#
# [1257 rows x 7 columns]

# %%
# check if there are any errors
errors = mane_results[mane_results['Error'].notna()]

if len(errors) > 0:
    print("\nEntries with errors:")
    print(errors[['Swiss-Prot AC', 'Error']].head())

# %% [markdown]
# Now we can combine the retrieved transcript mappings with the main dataset.

# %%
merged_df = data25_2.merge(mane_results, on="Swiss-Prot AC", how="left")
merged_df.rename(columns={'Swiss-Prot AC':'Uniprot'}, inplace=True)

# %% [markdown]
# Also, important to drop duplicate rows again!

# %%
merged_df=merged_df.drop_duplicates().reset_index(drop=True)
len(merged_df)
# Out:
# 3824

# %%
merged_df.head()
# Out:
#   Main gene name Uniprot        FTId     AA change Variant category  \
# 0          AARS1  P49588  VAR_089576   p.Arg326Trp             LP/P
# 1          AARS1  P49588  VAR_089577   p.Thr606Ile             LP/P
# 2          AARS1  P49588  VAR_089578   p.Ser698Phe             LP/P
# 3          ABCA4  P78363  VAR_084908  p.Asp1102Tyr             LB/B
# 4          ABCA4  P78363  VAR_084916  p.Gly1203Asp             LP/P
#
#          dbSNP                                       Disease name  Source  \
# 0            -  Charcot-Marie-Tooth disease, axonal, 2N (CMT2N...    2025
# 1            -  Leukoencephalopathy, hereditary diffuse, with ...    2025
# 2            -  Charcot-Marie-Tooth disease, axonal, 2N (CMT2N...    2025
# 3  rs138641544                                                NaN    2025
# 4            -           Stargardt disease 1 (STGD1) [MIM:248200]    2025
#
#   Variant BinaryClinicalSignificance      MANE-Select ID       Ensembl ID  \
# 0   R326W                          P  ENST00000261772.13  ENST00000261772
# 1   T606I                          P  ENST00000261772.13  ENST00000261772
# 2   S698F                          P  ENST00000261772.13  ENST00000261772
# 3  D1102Y                          B   ENST00000370225.4  ENST00000370225
# 4  G1203D                          P   ENST00000370225.4  ENST00000370225
#
#           Protein ID RefSeq Nucleotide ID RefSeq Protein ID Error
# 0  ENSP00000261772.8          NM_001605.3       NP_001596.2  None
# 1  ENSP00000261772.8          NM_001605.3       NP_001596.2  None
# 2  ENSP00000261772.8          NM_001605.3       NP_001596.2  None
# 3  ENSP00000359245.3          NM_000350.3       NP_000341.2  None
# 4  ENSP00000359245.3          NM_000350.3       NP_000341.2  None

# %%
merged_df.to_csv('../data/humsavar/humsavar_20212025_v2.csv',index=0)

# %% [markdown]
# We are ready to prepare input for the VEP tool and obtain predictions.

# %% [markdown]
# But there is a problem: Humsavar data is in Aa format, so there is no chromosome, genomic coordinate info etc (needed for VEPs).
#
# Possible solutions to this:
# - __Option 1__: Retrieve only those variants with dbSNP ID number
# - __Option 2__: Retrieve nucleotide change information from REVEL downloads (_Fail. Revel coverage is not wide enough_)
# - __Option 3__: Try generating VCF file for all those proteins from the transcript/exon information (_Time consuming_)
# - __Option 4__: Select 10 predictors and get predictions separately from each tool (_Maybe/Some tools still require genomic coodinate format_)

# %% [markdown]
# ### __Option 1__: Extract variants with a known dbSNP ID for easier mapping to genomic coordinates.

# %%
# load the cleaned dataset
merged_df = pd.read_csv('../data/humsavar/humsavar_20212025_v2.csv')

# %%
merged_df.dbSNP.nunique()
# Out:
# 2577

# %% [markdown]
# For this, we must identify duplicated dbSNP entries to review possible inconsistencies

# %%
# keep these in mind to check after
merged_df[merged_df.duplicated(subset=['dbSNP'], keep=False)].dbSNP.unique()
# Out:
# array(['-', 'rs1645264815', 'rs2153228682', 'rs1705222655', 'rs752450983',
#        'rs1599011050', 'rs1949512456', 'rs28642966', 'rs201552310',
#        'rs200005406', 'rs2072648', 'rs1057517926', 'rs1757708758',
#        'rs77834747', 'rs381427', 'rs421016', 'rs121908310', 'rs77933015',
#        'rs121908308', 'rs782199122', 'rs1191455921', 'rs2071312',
#        'rs104894264', 'rs7480563', 'rs7126405', 'rs2293232', 'rs2246901',
#        'rs200291894', 'rs571714796', 'rs7255187', 'rs1684813071',
#        'rs1554297905', 'rs1838076782', 'rs141269120', 'rs1057149',
#        'rs1385657144', 'rs1965499910'], dtype=object)

# %% [markdown]
# And remove those entries **without** dbSNP annotations.

# %%
# first, we drop duplicate entries while keeping the first occurrence
tmp=merged_df.drop_duplicates(subset='dbSNP', keep='first')

# and extract the list of valid dbSNP IDs
dbsnplist=list(tmp[tmp.dbSNP!='-'].dbSNP.values)

# %% [markdown]
# After the filtering we analyze the dataset coverage.

# %%
print("Total number of variants in the dataset:", len(merged_df)) 
print("Unique dbSNP IDs after removing duplicates:", len(dbsnplist)) 
print("Variants with dbSNP IDs:", len(merged_df[merged_df.dbSNP!='-']))
print("Unique proteins that have at least 1 variant with a dbSNP ID:", merged_df[merged_df.dbSNP!='-']['Uniprot'].nunique())  # Unique proteins with dbSNP mapped variants
# Out:
# Total number of variants in the dataset: 3824
# Unique dbSNP IDs after removing duplicates: 2576
# Variants with dbSNP IDs: 2613
# Unique proteins that have at least 1 variant with a dbSNP ID: 976

# %% [markdown]
# Important to save the filtered dbSNP IDs so we can further process them (with VEP)

# %%
with open('../data/humsavar/humsavar_rsIDs.txt', 'w') as f:
    for db in dbsnplist:
        f.write(f"{db}" + "\n")

# %% [markdown]
# The website VEP tool was used for ease of access since we only have rsIDs.
#
# Same options were selected as with ClinVar.

# %% [markdown]
# ### Read VEP output (predictions added!)

# %%
VEP_output = pd.read_csv('../data/humsavar/cleaned_Humsavar_dataset_outputVEP.txt', sep='\t')

# %%
VEP_output.head()
# Out:
#   #Uploaded_variation               Location Allele       Consequence    IMPACT SYMBOL             Gene Feature_type            Feature         BIOTYPE EXON INTRON                          HGVSc                         HGVSp cDNA_position CDS_position Protein_position Amino_acids   Codons    Existing_variation REF_ALLELE UPLOADED_ALLELE DISTANCE STRAND FLAGS SYMBOL_SOURCE   HGNC_ID         MANE  MANE_SELECT MANE_PLUS_CLINICAL TSL APPRIS        CCDS             ENSP   SWISSPROT         TREMBL        UNIPARC UNIPROT_ISOFORM                           SIFT                  PolyPhen HGVS_OFFSET AF AFR_AF AMR_AF EAS_AF EUR_AF SAS_AF gnomADe_AF gnomADe_AFR_AF gnomADe_AMR_AF gnomADe_ASJ_AF gnomADe_EAS_AF gnomADe_FIN_AF gnomADe_MID_AF gnomADe_NFE_AF gnomADe_REMAINING_AF gnomADe_SAS_AF gnomADg_AF gnomADg_AFR_AF gnomADg_AMI_AF gnomADg_AMR_AF gnomADg_ASJ_AF gnomADg_EAS_AF gnomADg_FIN_AF gnomADg_MID_AF gnomADg_NFE_AF gnomADg_REMAINING_AF gnomADg_SAS_AF                      CLIN_SIG SOMATIC PHENO                                                         PUBMED MOTIF_NAME MOTIF_POS HIGH_INF_POS MOTIF_SCORE_CHANGE TRANSCRIPTION_FACTORS  REVEL BLOSUM62  EVE_CLASS           EVE_SCORE CADD_PHRED  CADD_RAW           am_class am_pathogenicity 1000Gp3_AC 1000Gp3_AF 1000Gp3_AFR_AC 1000Gp3_AFR_AF 1000Gp3_AMR_AC 1000Gp3_AMR_AF 1000Gp3_EAS_AC 1000Gp3_EAS_AF 1000Gp3_EUR_AC 1000Gp3_EUR_AF 1000Gp3_SAS_AC 1000Gp3_SAS_AF ALFA_African_AC ALFA_African_AF ALFA_African_AN ALFA_African_American_AC ALFA_African_American_AF ALFA_African_American_AN ALFA_African_Others_AC ALFA_African_Others_AF ALFA_African_Others_AN ALFA_Asian_AC ALFA_Asian_AF ALFA_Asian_AN ALFA_East_Asian_AC ALFA_East_Asian_AF ALFA_East_Asian_AN ALFA_European_AC ALFA_European_AF ALFA_European_AN ALFA_Latin_American_1_AC ALFA_Latin_American_1_AF ALFA_Latin_American_1_AN ALFA_Latin_American_2_AC ALFA_Latin_American_2_AF ALFA_Latin_American_2_AN ALFA_Other_AC ALFA_Other_AF ALFA_Other_AN ALFA_Other_Asian_AC ALFA_Other_Asian_AF ALFA_Other_Asian_AN ALFA_South_Asian_AC ALFA_South_Asian_AF ALFA_South_Asian_AN ALFA_Total_AC ALFA_Total_AF ALFA_Total_AN ALSPAC_AC ALSPAC_AF Aloft_Confidence Aloft_Fraction_transcripts_affected Aloft_pred Aloft_prob_Dominant Aloft_prob_Recessive Aloft_prob_Tolerant AltaiNeandertal Ancestral_allele BayesDel_addAF_pred BayesDel_addAF_rankscore BayesDel_addAF_score BayesDel_noAF_pred BayesDel_noAF_rankscore BayesDel_noAF_score ChagyrskayaNeandertal DANN_rankscore           DANN_score DEOGEN2_pred DEOGEN2_rankscore      DEOGEN2_score Denisova ESM1b_pred ESM1b_rankscore ESM1b_score ESP6500_AA_AC ESP6500_AA_AF ESP6500_EA_AC ESP6500_EA_AF EVE_Class10_pred EVE_Class20_pred EVE_Class25_pred EVE_Class30_pred EVE_Class40_pred EVE_Class50_pred EVE_Class60_pred EVE_Class70_pred EVE_Class75_pred EVE_Class80_pred EVE_Class90_pred EVE_rankscore             EVE_score Eigen-PC-phred_coding Eigen-PC-raw_coding Eigen-PC-raw_coding_rankscore Eigen-phred_coding   Eigen-raw_coding Eigen-raw_coding_rankscore                   Ensembl_geneid                Ensembl_proteinid             Ensembl_transcriptid ExAC_AC ExAC_AF ExAC_AFR_AC ExAC_AFR_AF ExAC_AMR_AC ExAC_AMR_AF ExAC_Adj_AC ExAC_Adj_AF ExAC_EAS_AC ExAC_EAS_AF ExAC_FIN_AC ExAC_FIN_AF ExAC_NFE_AC ExAC_NFE_AF ExAC_SAS_AC ExAC_SAS_AF ExAC_nonTCGA_AC ExAC_nonTCGA_AF ExAC_nonTCGA_AFR_AC ExAC_nonTCGA_AFR_AF ExAC_nonTCGA_AMR_AC ExAC_nonTCGA_AMR_AF ExAC_nonTCGA_Adj_AC ExAC_nonTCGA_Adj_AF ExAC_nonTCGA_EAS_AC ExAC_nonTCGA_EAS_AF ExAC_nonTCGA_FIN_AC ExAC_nonTCGA_FIN_AF ExAC_nonTCGA_NFE_AC ExAC_nonTCGA_NFE_AF ExAC_nonTCGA_SAS_AC ExAC_nonTCGA_SAS_AF ExAC_nonpsych_AC ExAC_nonpsych_AF ExAC_nonpsych_AFR_AC ExAC_nonpsych_AFR_AF ExAC_nonpsych_AMR_AC ExAC_nonpsych_AMR_AF ExAC_nonpsych_Adj_AC ExAC_nonpsych_Adj_AF ExAC_nonpsych_EAS_AC ExAC_nonpsych_EAS_AF ExAC_nonpsych_FIN_AC ExAC_nonpsych_FIN_AF ExAC_nonpsych_NFE_AC ExAC_nonpsych_NFE_AF ExAC_nonpsych_SAS_AC ExAC_nonpsych_SAS_AF FATHMM_converted_rankscore FATHMM_pred FATHMM_score GERP++_NR GERP++_RS GERP++_RS_rankscor ...
# 0         rs121909521  1:229433067-229433067      G  missense_variant  MODERATE  ACTA1  ENSG00000143632   Transcript  ENST00000366683.4  protein_coding  2/7      -      ENST00000366683.4:c.49G>C  ENSP00000355644.4:p.Gly17Arg           162           49               17         G/R  Ggc/Cgc  rs121909521,CM992116          C           C/G/T        -     -1     -          HGNC  HGNC:129            -            -                  -   5      -           -  ENSP00000355644           -     A6NL76.108  UPI000C755200               -  deleterious_low_confidence(0)   probably_damaging(0.98)           -  -      -      -      -      -      -          -              -              -              -              -              -              -              -                    -              -          -              -              -              -              -              -              -              -              -                    -              -  likely_pathogenic,pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480          -         -            -                  -                     -  0.937       -2  Uncertain  0.6114285422903512       29.0  5.169387  likely_pathogenic           0.9989          -          -              -              -              -              -              -              -              -              -              -              -               -               -               -                        -                        -                        -                      -                      -                      -             -             -             -                  -                  -                  -                -                -                -                        -                        -                        -                        -                        -                        -             -             -             -                   -                   -                   -                   -                   -                   -             -             -             -         -         -             .,.,                                .,.,       .,.,                .,.,                 .,.,                .,.,             C/C                C                   D                  0.97007               0.5807                  D                 0.96957            0.596359                   C/C        0.77505  0.99654753831684295          D,D           0.98979  0.936956,0.608584      C/C        D,.         0.81140   -11.274,.             -             -             -             -              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              P,.       0.67905  0.6114285422903512,.              8.060451     0.7158844301797                       0.83587           10.34018  0.871517802988444                    0.90297  ENSG00000143632,ENSG00000143632  ENSP00000355645,ENSP00000355644  ENST00000366684,ENST00000366683       -       -           -           -           -           -           -           -           -           -           -           -           -           -           -           -               -               -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                -                -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    0.97317         D,D  -4.36,-3.44      4.77      3.85             0.4355 ...
# 1         rs121909521  1:229433067-229433067      T  missense_variant  MODERATE  ACTA1  ENSG00000143632   Transcript  ENST00000366683.4  protein_coding  2/7      -      ENST00000366683.4:c.49G>A  ENSP00000355644.4:p.Gly17Ser           162           49               17         G/S  Ggc/Agc  rs121909521,CM992116          C           C/G/T        -     -1     -          HGNC  HGNC:129            -            -                  -   5      -           -  ENSP00000355644           -     A6NL76.108  UPI000C755200               -  deleterious_low_confidence(0)  possibly_damaging(0.616)           -  -      -      -      -      -      -          -              -              -              -              -              -              -              -                    -              -          -              -              -              -              -              -              -              -              -                    -              -                    pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480          -         -            -                  -                     -  0.829        0  Uncertain  0.6114285422903512       29.3  5.215657  likely_pathogenic            0.977          -          -              -              -              -              -              -              -              -              -              -              -               -               -               -                        -                        -                        -                      -                      -                      -             -             -             -                  -                  -                  -                -                -                -                        -                        -                        -                        -                        -                        -             -             -             -                   -                   -                   -                   -                   -                   -             -             -             -         -         -             .,.,                                .,.,       .,.,                .,.,                 .,.,                .,.,             C/C                C                   D                  0.85812             0.339657                  D                 0.85626            0.250118                   C/C        0.77442  0.99653432494021255          D,D           0.98241  0.907821,0.506088      C/C        D,.         0.83878   -11.803,.             -             -             -             -              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.       0.61118  0.5415978678391965,.               6.02208   0.583422394626358                       0.73752           6.645705  0.664133181902103                    0.77286  ENSG00000143632,ENSG00000143632  ENSP00000355645,ENSP00000355644  ENST00000366684,ENST00000366683       -       -           -           -           -           -           -           -           -           -           -           -           -           -           -           -               -               -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                -                -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    0.97292         D,D  -4.35,-3.39      4.77      3.85             0.4355 ...
# 2         rs121909521  1:229433067-229433067      G  missense_variant  MODERATE  ACTA1  ENSG00000143632   Transcript  ENST00000366684.7  protein_coding  2/7      -      ENST00000366684.7:c.49G>C  ENSP00000355645.3:p.Gly17Arg           152           49               17         G/R  Ggc/Cgc  rs121909521,CM992116          C           C/G/T        -     -1     -          HGNC  HGNC:129  MANE_Select  NM_001100.4                  -   1     P1  CCDS1578.1  ENSP00000355645  P68133.190              -  UPI0000000860               -  deleterious_low_confidence(0)                         -           -  -      -      -      -      -      -          -              -              -              -              -              -              -              -                    -              -          -              -              -              -              -              -              -              -              -                    -              -  likely_pathogenic,pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480          -         -            -                  -                     -  0.937       -2  Uncertain  0.6114285422903512       29.0  5.169387  likely_pathogenic           0.9989          -          -              -              -              -              -              -              -              -              -              -              -               -               -               -                        -                        -                        -                      -                      -                      -             -             -             -                  -                  -                  -                -                -                -                        -                        -                        -                        -                        -                        -             -             -             -                   -                   -                   -                   -                   -                   -             -             -             -         -         -             .,.,                                .,.,       .,.,                .,.,                 .,.,                .,.,             C/C                C                   D                  0.97007               0.5807                  D                 0.96957            0.596359                   C/C        0.77505  0.99654753831684295          D,D           0.98979  0.936956,0.608584      C/C        D,.         0.81140   -11.274,.             -             -             -             -              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              P,.       0.67905  0.6114285422903512,.              8.060451     0.7158844301797                       0.83587           10.34018  0.871517802988444                    0.90297  ENSG00000143632,ENSG00000143632  ENSP00000355645,ENSP00000355644  ENST00000366684,ENST00000366683       -       -           -           -           -           -           -           -           -           -           -           -           -           -           -           -               -               -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                -                -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    0.97317         D,D  -4.36,-3.44      4.77      3.85             0.4355 ...
# 3         rs121909521  1:229433067-229433067      T  missense_variant  MODERATE  ACTA1  ENSG00000143632   Transcript  ENST00000366684.7  protein_coding  2/7      -      ENST00000366684.7:c.49G>A  ENSP00000355645.3:p.Gly17Ser           152           49               17         G/S  Ggc/Agc  rs121909521,CM992116          C           C/G/T        -     -1     -          HGNC  HGNC:129  MANE_Select  NM_001100.4                  -   1     P1  CCDS1578.1  ENSP00000355645  P68133.190              -  UPI0000000860               -  deleterious_low_confidence(0)                         -           -  -      -      -      -      -      -          -              -              -              -              -              -              -              -                    -              -          -              -              -              -              -              -              -              -              -                    -              -                    pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480          -         -            -                  -                     -  0.829        0  Uncertain  0.6114285422903512       29.3  5.215657  likely_pathogenic            0.977          -          -              -              -              -              -              -              -              -              -              -              -               -               -               -                        -                        -                        -                      -                      -                      -             -             -             -                  -                  -                  -                -                -                -                        -                        -                        -                        -                        -                        -             -             -             -                   -                   -                   -                   -                   -                   -             -             -             -         -         -             .,.,                                .,.,       .,.,                .,.,                 .,.,                .,.,             C/C                C                   D                  0.85812             0.339657                  D                 0.85626            0.250118                   C/C        0.77442  0.99653432494021255          D,D           0.98241  0.907821,0.506088      C/C        D,.         0.83878   -11.803,.             -             -             -             -              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.              U,.       0.61118  0.5415978678391965,.               6.02208   0.583422394626358                       0.73752           6.645705  0.664133181902103                    0.77286  ENSG00000143632,ENSG00000143632  ENSP00000355645,ENSP00000355644  ENST00000366684,ENST00000366683       -       -           -           -           -           -           -           -           -           -           -           -           -           -           -           -               -               -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                -                -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    0.97292         D,D  -4.35,-3.39      4.77      3.85             0.4355 ...
# 4         rs121909521  1:229433067-229433067      G    intron_variant  MODIFIER  ACTA1  ENSG00000143632   Transcript  ENST00000684723.1  protein_coding    -    1/5  ENST00000684723.1:c.-6-187G>C                             -             -            -                -           -        -  rs121909521,CM992116          C           C/G/T        -     -1     -          HGNC  HGNC:129            -            -                  -   -      -           -  ENSP00000508084           -  A0A804HKV3.12  UPI0002C35578               -                              -                         -           -  -      -      -      -      -      -          -              -              -              -              -              -              -              -                    -              -          -              -              -              -              -              -              -              -              -                    -              -  likely_pathogenic,pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480          -         -            -                  -                     -      -        -          -                   -       29.0  5.169387                  -                -          -          -              -              -              -              -              -              -              -              -              -              -               -               -               -                        -                        -                        -                      -                      -                      -             -             -             -                  -                  -                  -                -                -                -                        -                        -                        -                        -                        -                        -             -             -             -                   -                   -                   -                   -                   -                   -             -             -             -         -         -                -                                   -          -                   -                    -                   -               -                -                   -                        -                    -                  -                       -                   -                     -              -                    -            -                 -                  -        -          -               -           -             -             -             -             -                -                -                -                -                -                -                -                -                -                -                -             -                     -                     -                   -                             -                  -                  -                          -                                -                                -                                -       -       -           -           -           -           -           -           -           -           -           -           -           -           -           -           -               -               -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                   -                -                -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                    -                          -           -            -         -         -                    ...

# %%
VEP_output["SYMBOL"].nunique()
# Out:
# 1469

# %%
VEP_output['#Uploaded_variation'].nunique()
# Out:
# 2574

# %%
VEP_output.shape
# Out:
# (61256, 480)

# %%
VEP_output.columns
# Out:
# Index(['#Uploaded_variation', 'Location', 'Allele', 'Consequence', 'IMPACT',
#        'SYMBOL', 'Gene', 'Feature_type', 'Feature', 'BIOTYPE',
#        ...
#        'phastCons17way_primate_rankscore', 'phastCons470way_mammalian',
#        'phastCons470way_mammalian_rankscore', 'phyloP100way_vertebrate',
#        'phyloP100way_vertebrate_rankscore', 'phyloP17way_primate',
#        'phyloP17way_primate_rankscore', 'phyloP470way_mammalian',
#        'phyloP470way_mammalian_rankscore', 'ClinPred'],
#       dtype='object', length=480)

# %%
VEP_output[["SIFT", "PolyPhen"]].head(2)
# Out:
#                             SIFT                  PolyPhen
# 0  deleterious_low_confidence(0)   probably_damaging(0.98)
# 1  deleterious_low_confidence(0)  possibly_damaging(0.616)

# %% [markdown]
# The VEP output from dbSNP is quite messy (lot of useless columns, differing column names...), similar to ClinVar. To streamline the pipeline, I created a separate script to parse the output. The script primarily splits predictor columns into labels and scores, and renames certain columns to facilitate easier merging.

# %%
VEP_output_parsed = pd.read_csv('../data/humsavar/cleaned_Humsavar_dataset_parsed.txt', sep=',')

# %%
VEP_output_parsed.head(2)
# Out:
#   #Uploaded_variation               Location Allele       Consequence    IMPACT GeneSymbol             Gene Feature_type            Feature cDNA_position CDS_position Protein_position Amino_acids   Codons    Existing_variation REF_ALLELE   HGNC_ID             ENSP SWISSPROT      TREMBL        UNIPARC UNIPROT_ISOFORM                  SIFT_label  SIFT_score     PolyPhen_label  PolyPhen_score AF                      CLIN_SIG SOMATIC PHENO                                                         PUBMED TRANSCRIPTION_FACTORS REVEL_score BLOSUM62  EVE_label           EVE_score CADD_PHRED_score CADD_RAW_score           AM_label AM_score BayesDel_label BayesDel_score PrimateAI_label PrimateAI_score    Uniprot_acc            Uniprot_entry clinvar_id                                        clinvar_review     ClinPred_score
# 0         rs121909521  1:229433067-229433067      G  missense_variant  MODERATE      ACTA1  ENSG00000143632   Transcript  ENST00000366683.4           162           49               17         G/R  Ggc/Cgc  rs121909521,CM992116          C  HGNC:129  ENSP00000355644         -  A6NL76.108  UPI000C755200               -  deleterious_low_confidence         0.0  probably_damaging           0.980  -  likely_pathogenic,pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480                     -       0.937       -2  Uncertain  0.6114285422903512             29.0       5.169387  likely_pathogenic   0.9989              D         0.5807               D  0.936415195465  P68133,A6NL76  ACTS_HUMAN,A6NL76_HUMAN      18281  criteria_provided,_multiple_submitters,_no_conflicts  0.999560415744781
# 1         rs121909521  1:229433067-229433067      T  missense_variant  MODERATE      ACTA1  ENSG00000143632   Transcript  ENST00000366683.4           162           49               17         G/S  Ggc/Agc  rs121909521,CM992116          C  HGNC:129  ENSP00000355644         -  A6NL76.108  UPI000C755200               -  deleterious_low_confidence         0.0  possibly_damaging           0.616  -                    pathogenic     0,1   1,1  10508519,9185179,15226407,17227580,29274205,23294764,20621480                     -       0.829        0  Uncertain  0.6114285422903512             29.3       5.215657  likely_pathogenic    0.977              D       0.339657               D   0.90714931488  P68133,A6NL76  ACTS_HUMAN,A6NL76_HUMAN     951759                   criteria_provided,_single_submitter  0.994793236255646

# %%
VEP_output_parsed[['SIFT_score', 'PolyPhen_score', 'CADD_RAW_score', 'CADD_PHRED_score', 'ClinPred_score', 'EVE_score', 'REVEL_score', 'PrimateAI_score', 'AM_score']].isna().sum()
# Out:
# SIFT_score          44465
# PolyPhen_score      44866
# CADD_RAW_score          0
# CADD_PHRED_score        0
# ClinPred_score          0
# EVE_score               0
# REVEL_score             0
# PrimateAI_score         0
# AM_score                0
# dtype: int64

# %% [markdown]
# Some function to check coverage of results

# %%
def check_coverage(df):
    predictors = [i for i in df.columns if '_score' in i]
    adding = []
    predictor_groups = {'CADD': ['CADD_RAW_score', 'CADD_PHRED_score']}

    for predictor in predictors:
        if predictor in predictor_groups.get('CADD', []):
            coverage_type = 'RAW' if 'RAW' in predictor else 'PHRED'
            predictor_label = f'CADD ({coverage_type})'
        else:
            predictor_label = predictor.split('_')[0]
            if predictor_label == 'AM':
                predictor_label = 'AlphaMissense' 

        tmp = df[df[predictor].notna()]  
        coverage = round(100 * len(tmp) / len(df), 2)
        adding.append([predictor_label, coverage])

    table = pd.DataFrame(adding, columns=['Predictor', 'Coverage'])
    table = table.sort_values('Coverage', ascending=False).reset_index(drop=True)
    return table

# %%
check_coverage(VEP_output_parsed)
# Out:
#        Predictor  Coverage
# 0            EVE    100.00
# 1          REVEL    100.00
# 2  AlphaMissense    100.00
# 3       BayesDel    100.00
# 4   CADD (PHRED)    100.00
# 5     CADD (RAW)    100.00
# 6      PrimateAI    100.00
# 7       ClinPred    100.00
# 8           SIFT     27.41
# 9       PolyPhen     26.76

# %% [markdown]
# Finally, we need to merge the VEP output with the original Humsavar dataset. Since the input for VEP was a list of dbSNP IDs, we filter for these IDs. In cases where multiple rows match (which happens because VEP identifies several transcript IDs), we select the row with the fewest NaNs, as this is considered the most reliable.

# %%
#   python3 merging_Humsavar.py cleaned_Humsavar_dataset_parsed.txt humsavar_rsIDs.txt

# %% [markdown]
# And now we can compare how both datasets (ClinVar and Humsavar) differ in terms of variants.

# %%
humsavar = pd.read_csv('../data/humsavar/cleaned_Humsavar_dataset_with_preds.txt')
humsavar.head(3)
# Out:
#   #Uploaded_variation             Location Allele       Consequence    IMPACT GeneSymbol             Gene Feature_type            Feature cDNA_position CDS_position Protein_position Amino_acids   Codons                  Existing_variation REF_ALLELE  HGNC_ID             ENSP   SWISSPROT TREMBL        UNIPARC UNIPROT_ISOFORM                  SIFT_label  SIFT_score     PolyPhen_label  PolyPhen_score      AF                           CLIN_SIG SOMATIC  PHENO             PUBMED TRANSCRIPTION_FACTORS REVEL_score BLOSUM62 EVE_label EVE_score CADD_PHRED_score CADD_RAW_score           AM_label AM_score BayesDel_label BayesDel_score PrimateAI_label PrimateAI_score    Uniprot_acc             Uniprot_entry clinvar_id                                        clinvar_review      ClinPred_score  NaN_count
# 0         rs138641544  1:94042785-94042785      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          3407         3304             1102         D/Y  Gat/Tat  rs138641544,CM1213230,COSV64674089          C  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.00  probably_damaging           0.980       -  uncertain_significance,pathogenic   0,1,1  1,1,1  22427542,20029649                     -       0.973       -3         -         -             28.6       5.116382  likely_pathogenic   0.7141              D       0.325626               D  0.804868936539         P78363               ABCA4_HUMAN    1456034        criteria_provided,_conflicting_classifications   0.938792994866256        0.0
# 1          rs76258939  1:94037332-94037332      G  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          3729         3626             1209         M/T  aTg/aCg                 rs76258939,HM080053          A  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -    tolerated_low_confidence        0.99             benign           0.000  0.0090               benign,likely_benign     0,1    1,1  25377941,37510153                     -       0.160       -1         -         -            6.791       0.635554      likely_benign   0.0833              T      -0.405625               T  0.344550430775  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN     143075  criteria_provided,_multiple_submitters,_no_conflicts  0.0247329644211997        NaN
# 2         rs185093512  1:94021904-94021904      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          4818         4715             1572         T/M  aCg/aTg   rs185093512,CM020913,COSV64679706          G  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.04             benign           0.322  0.0008             uncertain_significance   0,1,1  1,1,1           23982839                     -       0.597       -1         -         -            19.07       2.517531      likely_benign   0.1055              T     0.00427494               T  0.435085892677  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN     497936  criteria_provided,_multiple_submitters,_no_conflicts  0.0644443726981652        0.0

# %%
def extract_uniprot_id(Uniprot_acc, reviewed_ids):
    if pd.notna(Uniprot_acc):
        acc_ids = [acc.strip() for acc in Uniprot_acc.split(',')]
        for acc_id in acc_ids:
            if acc_id in reviewed_ids:
                return acc_id
    return None

# %%
with open('uniprotkb_reviewed_true_AND_organism_id_2025_04_09.list') as f:
    reviewed_ids = set(line.strip() for line in f if line.strip())

# %%
humsavar['UniprotID'] = humsavar.apply(lambda row: extract_uniprot_id(row['Uniprot_acc'], reviewed_ids), axis=1)

# %%
humsavar.head()
# Out:
#   #Uploaded_variation             Location Allele       Consequence    IMPACT GeneSymbol             Gene Feature_type            Feature cDNA_position CDS_position Protein_position Amino_acids   Codons                  Existing_variation REF_ALLELE  HGNC_ID             ENSP   SWISSPROT TREMBL        UNIPARC UNIPROT_ISOFORM                  SIFT_label  SIFT_score     PolyPhen_label  PolyPhen_score      AF                           CLIN_SIG SOMATIC  PHENO             PUBMED TRANSCRIPTION_FACTORS REVEL_score BLOSUM62 EVE_label EVE_score CADD_PHRED_score CADD_RAW_score           AM_label AM_score BayesDel_label BayesDel_score PrimateAI_label PrimateAI_score    Uniprot_acc             Uniprot_entry clinvar_id                                        clinvar_review      ClinPred_score  NaN_count UniprotID
# 0         rs138641544  1:94042785-94042785      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          3407         3304             1102         D/Y  Gat/Tat  rs138641544,CM1213230,COSV64674089          C  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.00  probably_damaging           0.980       -  uncertain_significance,pathogenic   0,1,1  1,1,1  22427542,20029649                     -       0.973       -3         -         -             28.6       5.116382  likely_pathogenic   0.7141              D       0.325626               D  0.804868936539         P78363               ABCA4_HUMAN    1456034        criteria_provided,_conflicting_classifications   0.938792994866256        0.0    P78363
# 1          rs76258939  1:94037332-94037332      G  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          3729         3626             1209         M/T  aTg/aCg                 rs76258939,HM080053          A  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -    tolerated_low_confidence        0.99             benign           0.000  0.0090               benign,likely_benign     0,1    1,1  25377941,37510153                     -       0.160       -1         -         -            6.791       0.635554      likely_benign   0.0833              T      -0.405625               T  0.344550430775  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN     143075  criteria_provided,_multiple_submitters,_no_conflicts  0.0247329644211997        NaN    P78363
# 2         rs185093512  1:94021904-94021904      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          4818         4715             1572         T/M  aCg/aTg   rs185093512,CM020913,COSV64679706          G  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.04             benign           0.322  0.0008             uncertain_significance   0,1,1  1,1,1           23982839                     -       0.597       -1         -         -            19.07       2.517531      likely_benign   0.1055              T     0.00427494               T  0.435085892677  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN     497936  criteria_provided,_multiple_submitters,_no_conflicts  0.0644443726981652        0.0    P78363
# 3        rs1571257969  1:94021390-94021390      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          4971         4868             1623         G/V  gGc/gTc               rs1571257969,CM161726          C  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.00  probably_damaging           0.995       -                  likely_pathogenic     0,1    1,1                  -                     -       0.889       -3         -         -             28.6       5.113081  likely_pathogenic   0.9468              D       0.446068               T  0.728230714798  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN     806162                   criteria_provided,_single_submitter   0.999383926391602        0.0    P78363
# 4         rs201357151  1:94010822-94010822      A  missense_variant  MODERATE      ABCA4  ENSG00000198691   Transcript  ENST00000370225.4          5795         5692             1898         R/C  Cgc/Tgc                         rs201357151          G  HGNC:34  ENSP00000359245  P78363.219      -  UPI000012511C               -  deleterious_low_confidence        0.00             benign           0.322  0.0002             uncertain_significance       -      1  25474345,33375396                     -       0.383       -3         -         -             21.5       3.137553      likely_benign   0.1062              T      -0.156535               T  0.204550027847  F6TT59,P78363  F6TT59_HUMAN,ABCA4_HUMAN    1013243  criteria_provided,_multiple_submitters,_no_conflicts  0.0601704447952564        0.0    P78363

# %%
reviewed_df = humsavar[humsavar['UniprotID'].notna()]

# %%
reviewed_df.shape
# Out:
# (2005, 51)

# %%
print(len(reviewed_df))
print(reviewed_df.UniprotID.nunique())
print(reviewed_df['GeneSymbol'].nunique())
# Out:
# 2005
# 686
# 686

# %%
print(humsavar.groupby('GeneSymbol')['UniprotID'].nunique().eq(1).loc[lambda x: ~x])
# Out:
# GeneSymbol
# -                False
# ABHD1            False
# ACTL9            False
# ADH1B            False
# ADRB1            False
# AHI1-DT          False
# AIP              False
# ALDH1B1          False
# ANKRD35          False
# AP1B1            False
# APOB             False
# APOL2            False
# ARHGEF25         False
# ART4             False
# ASCL3            False
# ATRX             False
# AURKA            False
# AXIN2            False
# B4GALNT1         False
# BBS2             False
# BCORL1           False
# BRCA2            False
# BTBD8            False
# C14orf178        False
# C5orf60          False
# C8B              False
# CALCR            False
# CALCRL           False
# CAPN1            False
# CARD8            False
# CCDC144NL-AS1    False
# CCDC168          False
# CCL15            False
# CCL23            False
# CD200R1          False
# CDKL1            False
# CDKN1C           False
# CDSN             False
# CEACAM21         False
# CEACAM5          False
# CEACAM6          False
# CEACAM7          False
# CEP126           False
# CGN              False
# CNDP1            False
# COL1A1           False
# COQ2             False
# CP               False
# CROCC            False
# CYP21A2          False
# CYP2C19          False
# CYP51A1          False
# DBT              False
# DDO              False
# DDX52            False
# DHRS4L2          False
# DMAC2L           False
# DMD              False
# DNAH1            False
# DOCK8            False
# DPY19L2P2        False
# DRD3             False
# ENPP7            False
# ERCC6L2          False
# EXOC3            False
# EXPH5            False
# F13A1            False
# FABP2            False
# FAM120C          False
# FAM169BP         False
# FAU              False
# FBXL6            False
# FCGR3B           False
# FER1L6-AS2       False
# FOCAD            False
# FREM2            False
# FRMD6            False
# FSHR             False
# FUT3             False
# FUT7             False
# GABRQ            False
# GAGE10           False
# GAGE12J          False
# GCN1             False
# GDF5             False
# GNA15            False
# GPIHBP1          False
# GSDMB            False
# GTSE1            False
# GYPA             False
# H2BW1            False
# HBG1             False
# HDLBP            False
# HECTD1           False
# HEXB             False
# HIVEP1           False
# HLA-DMB          False
# HNF1A            False
# HOXA1            False
# HPD              False
# HSF5             False
# HSP90AA2P        False
# HTR2C            False
# IFNA2            False
# IKBKE-AS1        False
# IL13             False
# ITGA2            False
# ITGB2            False
# KCNJ11           False
# KCNK15           False
# KCNK16           False
# KICS2            False
# KIF25-AS1        False
# KIF3C            False
# KIR2DL1          False
# KIRREL2          False
# KLKB1            False
# KLRC2            False
# KLRK1            False
# KPLCE            False
# KRT10-AS1        False
# KRTAP10-4        False
# KRTAP10-5        False
# KRTAP10-6        False
# KRTAP6-3         False
# LAIR1            False
# LAMA3            False
# LAMA4            False
# LENG1            False
# LGALS16          False
# LILRA4           False
# LILRB2           False
# LILRB5           False
# LINC00114        False
# LINC00303        False
# LINC00322        False
# LINC00336        False
# LINC00482        False
# LINC00523        False
# LINC00526        False
# LINC00574        False
# LINC01554        False
# LINC01555        False
# LINC01556        False
# LINC01559        False
# LINC01587        False
# LINC01600        False
# LINC02694        False
# LINC02914        False
# LINC03042        False
# LINC03122        False
# LPA              False
# LURAP1L          False
# LYAR             False
# MACF1            False
# MAGEA5P          False
# MARCHF1          False
# METTL25B         False
# MICAL2           False
# MIR1915          False
# MRGPRG           False
# MTCL2            False
# MTHFD1           False
# MUC2             False
# MUC4             False
# MYCBPAP          False
# MYOM2            False
# NALF2            False
# NAT2             False
# NBPF7P           False
# NCR1             False
# NDUFV1           False
# NEFH             False
# NFKBIL1          False
# NPVF             False
# NPY4R            False
# NR1D2            False
# NT5DC4           False
# NUDT1            False
# OPN1LW           False
# OR10G2           False
# OR51E1           False
# OR52L1           False
# OR6J1            False
# OR9H1P           False
# ORM1             False
# OTOGL            False
# OVCH1            False
# OXA1L            False
# PAK6             False
# PAK6-AS1         False
# PCDHB16          False
# PCDHB5           False
# PCDHB6           False
# PCDHB9           False
# PFN2-AS1         False
# PKD1L1           False
# PLAU             False
# PLXNA3           False
# POLR3K           False
# PPP1R15B         False
# PPP1R1A          False
# PRB2             False
# PRB3             False
# PRH2             False
# PRM3             False
# PRODH            False
# PRPH2            False
# RBM20            False
# RBM44            False
# RCC1L            False
# RDUR             False
# RGL3             False
# RGMA             False
# RHCE             False
# RHOD             False
# RNF31            False
# RPL10            False
# RUSC1-AS1        False
# SAA1             False
# SALL2            False
# SCRT1            False
# SELP             False
# SEMA6A           False
# SEPTIN1          False
# SERPINB11        False
# SFTPA2           False
# SFTPC            False
# SHPK             False
# SLC19A4P         False
# SLC22A18         False
# SLC23A1          False
# SLC5A3           False
# SLC66A1LP        False
# SLCO2B1          False
# SMAD5-AS1        False
# SMC1B            False
# SOWAHA           False
# SPANXN3          False
# SPECC1L          False
# SPMIP6           False
# SPON2            False
# SPRYD4           False
# SRD5A2           False
# SUMO4            False
# SUN1             False
# SURF2            False
# SYNM             False
# TAPBP            False
# TARM1            False
# TAS2R42          False
# TBC1D17          False
# TBX2             False
# TENT4A           False
# TFAP2A-AS1       False
# TGFB1            False
# TMEM185A         False
# TMEM225          False
# TMPRSS11A        False
# TNFRSF10D        False
# TPSB2            False
# TPSG1            False
# TRIM50           False
# TRMT5            False
# TRPC3            False
# TRPV5            False
# TSHR             False
# TTLL6            False
# TUFM             False
# UMODL1-AS1       False
# UTP25            False
# VGLL4            False
# VN1R4            False
# VPS35L           False
# WDR13            False
# WNK2             False
# XRCC1            False
# YWHAH-AS1        False
# ZBTB8OS          False
# ZFYVE26          False
# ZG16             False
# ZNF180           False
# ZNF22            False
# ZNF229           False
# ZNF280A          False
# ZNF280B          False
# ZNF285           False
# ZNF469           False
# ZNF668           False
# ZNF708           False
# Name: UniprotID, dtype: bool

# %% [markdown]
# These correspond to genes that are mapped to more than one Uniprot ID, which makes no sense. After, we show how reviewed_df has all its genes mapped to a single ID.

# %%
print(reviewed_df.groupby('GeneSymbol')['UniprotID'].nunique().eq(1).loc[lambda x: ~x])
# Out:
# Series([], Name: UniprotID, dtype: bool)

# %% [markdown]
# Finally, we proceed to remove those variants that were already retrieved on ClinVar, so we can just take new ones from Humsavar.

# %%
reviewed_df.shape
# Out:
# (2005, 51)

# %%
with open('/home/aitanadiaz/Desktop/TFG/Cleaning data/data/clinvar/clinvar_unique_uniprot_ids.txt') as f:
    clinvar_unique_ids = set(line.strip() for line in f if line.strip())

filtered_df = reviewed_df[~reviewed_df['UniprotID'].isin(clinvar_unique_ids)]

# %%
filtered_df.shape
# Out:
# (1108, 51)

# %%
#print(humsavar_no_clinvar.BinaryClinicalSignificance.value_counts())

print(len(filtered_df))
print(filtered_df.UniprotID.nunique())
print(filtered_df['GeneSymbol'].nunique())
# Out:
# 1108
# 469
# 469

# %%
check_coverage(filtered_df)
# Out:
#        Predictor  Coverage
# 0            EVE    100.00
# 1          REVEL    100.00
# 2  AlphaMissense    100.00
# 3       BayesDel    100.00
# 4   CADD (PHRED)    100.00
# 5     CADD (RAW)    100.00
# 6      PrimateAI    100.00
# 7       ClinPred    100.00
# 8           SIFT     99.55
# 9       PolyPhen     98.83

# %%
humsavar_no_clinvar=filtered_df.reset_index(drop=True)
humsavar_no_clinvar.to_csv('../data/humsavar/humsavar_no_clinvar.csv', index=0)

# %% [markdown]
# As to calculate performance metrics we need the true pathogenicity values of the variants, the Variant category column must be added.

# %%
humsavar_withVarCat = pd.read_csv('/home/aitanadiaz/Desktop/TFG/Cleaning data/data/humsavar/humsavar_20212025_v2.csv', sep=',')

# %%
humsavar_withVarCat.head()
# Out:
#   Main gene name Uniprot        FTId     AA change Variant category        dbSNP                                                                    Disease name  Source Variant BinaryClinicalSignificance      MANE-Select ID       Ensembl ID         Protein ID RefSeq Nucleotide ID RefSeq Protein ID  Error
# 0          AARS1  P49588  VAR_089576   p.Arg326Trp             LP/P            -                    Charcot-Marie-Tooth disease, axonal, 2N (CMT2N) [MIM:613287]    2025   R326W                          P  ENST00000261772.13  ENST00000261772  ENSP00000261772.8          NM_001605.3       NP_001596.2    NaN
# 1          AARS1  P49588  VAR_089577   p.Thr606Ile             LP/P            -  Leukoencephalopathy, hereditary diffuse, with spheroids 2 (HDLS2) [MIM:619661]    2025   T606I                          P  ENST00000261772.13  ENST00000261772  ENSP00000261772.8          NM_001605.3       NP_001596.2    NaN
# 2          AARS1  P49588  VAR_089578   p.Ser698Phe             LP/P            -                    Charcot-Marie-Tooth disease, axonal, 2N (CMT2N) [MIM:613287]    2025   S698F                          P  ENST00000261772.13  ENST00000261772  ENSP00000261772.8          NM_001605.3       NP_001596.2    NaN
# 3          ABCA4  P78363  VAR_084908  p.Asp1102Tyr             LB/B  rs138641544                                                                             NaN    2025  D1102Y                          B   ENST00000370225.4  ENST00000370225  ENSP00000359245.3          NM_000350.3       NP_000341.2    NaN
# 4          ABCA4  P78363  VAR_084916  p.Gly1203Asp             LP/P            -                                        Stargardt disease 1 (STGD1) [MIM:248200]    2025  G1203D                          P   ENST00000370225.4  ENST00000370225  ENSP00000359245.3          NM_000350.3       NP_000341.2    NaN

# %%
humsavar_withVarCat.shape
# Out:
# (3824, 16)

# %%
hum_no_clin = pd.read_csv('/home/aitanadiaz/Desktop/TFG/Cleaning data/data/humsavar/humsavar_no_clinvar.csv', sep=',')

# %%
hum_no_clin.head()
# Out:
#   #Uploaded_variation                Location Allele       Consequence    IMPACT GeneSymbol             Gene Feature_type             Feature  cDNA_position  CDS_position  Protein_position Amino_acids   Codons        Existing_variation REF_ALLELE     HGNC_ID             ENSP   SWISSPROT TREMBL        UNIPARC UNIPROT_ISOFORM                  SIFT_label  SIFT_score     PolyPhen_label  PolyPhen_score      AF                 CLIN_SIG SOMATIC PHENO    PUBMED TRANSCRIPTION_FACTORS REVEL_score  BLOSUM62 EVE_label EVE_score  CADD_PHRED_score  CADD_RAW_score           AM_label AM_score BayesDel_label BayesDel_score PrimateAI_label PrimateAI_score                             Uniprot_acc                                                  Uniprot_entry clinvar_id                  clinvar_review      ClinPred_score  NaN_count UniprotID
# 0          rs11610050  12:107651687-107651687      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           3512          3005              1002         A/D  gCt/gAt                rs11610050          C  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1  deleterious_low_confidence        0.00  probably_damaging           0.972       -                        -       -     -         -                     -       0.649        -2         -         -              31.0        5.339176  likely_pathogenic   0.9994              D       0.356338               D  0.848108232021       A6QL63,A6QL63-2,A6QL63-5,A6QL63-4                BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN          -                               -   0.999407649040222        0.0    A6QL63
# 1          rs12303478  12:107657629-107657629      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           3733          3226              1076         G/S  Ggc/Agc  rs12303478,COSV104383452          G  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1    tolerated_low_confidence        0.09             benign           0.049  0.1048                        -     0,1   0,1         -                     -       0.072         0         -         -              22.4        3.396815      likely_benign   0.0921              T      -0.583583               T  0.613067984581       A6QL63,A6QL63-2,A6QL63-5,A6QL63-4                BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN          -                               -  0.0157182390193226        0.0    A6QL63
# 2           rs1558781  12:107543991-107543991      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           1849          1342               448         G/S  Ggc/Agc    rs1558781,COSV99774826          G  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1    tolerated_low_confidence        0.43             benign           0.022  0.1763                        -     0,1   0,1         -                     -       0.102         0         -         -              22.3        3.373019      likely_benign   0.0774              T      -0.626984               T  0.485189527273  A6QL63,A6QL63-2,A6QL63-3,H0YHR1,C9JV03  BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,H0YHR1_HUMAN,C9JV03_HUMAN          -                               -  0.0154826749531858        0.0    A6QL63
# 3         rs200582844   2:236581237-236581237      A  missense_variant  MODERATE      ACKR3  ENSG00000144476   Transcript   ENST00000272928.4            898           772               258         V/M  Gtg/Atg  rs200582844,COSV56021506          G  HGNC:23692  ENSP00000272928  P25106.214      -  UPI000013D989               -                 deleterious        0.03  probably_damaging           0.978       -  pathogenic,not_provided     0,1   1,1  31211835                     -       0.494         1         -         -              26.3        4.697178          ambiguous   0.5384              D       0.143901               T  0.672353982925                                  P25106                                                    ACKR3_HUMAN     585134  no_assertion_criteria_provided   0.863086182351898        0.0    P25106
# 4         rs767323284    13:76955344-76955344      T  missense_variant  MODERATE      ACOD1  ENSG00000102794   Transcript   ENST00000377462.6            338           290                97         T/M  aCg/aTg  rs767323284,COSV66291594          C  HGNC:33904  ENSP00000366682  A6NK06.110      -  UPI000015C60D               -                   tolerated        0.14  probably_damaging           0.958       -                        -     0,1   0,1  31548418                     -       0.613        -1         -         -              24.4        4.135920          ambiguous   0.3837              D       0.316682               T  0.677448093891                           A6NK06,H7C1Q4                                        IRG1_HUMAN,H7C1Q4_HUMAN          -                               -   0.957577884197235        0.0    A6NK06

# %%
hum_no_clin["#Uploaded_variation"].nunique()
# Out:
# 1108

# %%
hum_no_clin.shape
# Out:
# (1108, 51)

# %%
humsavar_withVarCat['dbSNP'] = humsavar_withVarCat['dbSNP'].astype(str)
hum_no_clin['#Uploaded_variation'] = hum_no_clin['#Uploaded_variation'].astype(str)

merged_df = pd.merge(
    humsavar_withVarCat,
    hum_no_clin,
    left_on='dbSNP',
    right_on='#Uploaded_variation',
    how='right'
)

# %%
merged_df.head()
# Out:
#   Main gene name Uniprot        FTId     AA change Variant category        dbSNP                                          Disease name  Source Variant BinaryClinicalSignificance      MANE-Select ID       Ensembl ID         Protein ID RefSeq Nucleotide ID RefSeq Protein ID  Error #Uploaded_variation                Location Allele       Consequence    IMPACT GeneSymbol             Gene Feature_type             Feature  cDNA_position  CDS_position  Protein_position Amino_acids   Codons        Existing_variation REF_ALLELE     HGNC_ID             ENSP   SWISSPROT TREMBL        UNIPARC UNIPROT_ISOFORM                  SIFT_label  SIFT_score     PolyPhen_label  PolyPhen_score      AF                 CLIN_SIG SOMATIC PHENO    PUBMED TRANSCRIPTION_FACTORS REVEL_score  BLOSUM62 EVE_label EVE_score  CADD_PHRED_score  CADD_RAW_score           AM_label AM_score BayesDel_label BayesDel_score PrimateAI_label PrimateAI_score                             Uniprot_acc                                                  Uniprot_entry clinvar_id                  clinvar_review      ClinPred_score  NaN_count UniprotID
# 0          ABTB3  A6QL63  VAR_042534  p.Ala1002Asp             LB/B   rs11610050                                                   NaN    2025  A1002D                          B  ENST00000280758.10  ENST00000280758  ENSP00000280758.5       NM_001018072.2    NP_001018082.1    NaN          rs11610050  12:107651687-107651687      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           3512          3005              1002         A/D  gCt/gAt                rs11610050          C  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1  deleterious_low_confidence        0.00  probably_damaging           0.972       -                        -       -     -         -                     -       0.649        -2         -         -              31.0        5.339176  likely_pathogenic   0.9994              D       0.356338               D  0.848108232021       A6QL63,A6QL63-2,A6QL63-5,A6QL63-4                BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN          -                               -   0.999407649040222        0.0    A6QL63
# 1          ABTB3  A6QL63  VAR_042535  p.Gly1076Ser             LB/B   rs12303478                                                   NaN    2025  G1076S                          B  ENST00000280758.10  ENST00000280758  ENSP00000280758.5       NM_001018072.2    NP_001018082.1    NaN          rs12303478  12:107657629-107657629      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           3733          3226              1076         G/S  Ggc/Agc  rs12303478,COSV104383452          G  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1    tolerated_low_confidence        0.09             benign           0.049  0.1048                        -     0,1   0,1         -                     -       0.072         0         -         -              22.4        3.396815      likely_benign   0.0921              T      -0.583583               T  0.613067984581       A6QL63,A6QL63-2,A6QL63-5,A6QL63-4                BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN          -                               -  0.0157182390193226        0.0    A6QL63
# 2          ABTB3  A6QL63  VAR_055560   p.Gly448Ser             LB/B    rs1558781                                                   NaN    2025   G448S                          B  ENST00000280758.10  ENST00000280758  ENSP00000280758.5       NM_001018072.2    NP_001018082.1    NaN           rs1558781  12:107543991-107543991      A  missense_variant  MODERATE      ABTB3  ENSG00000151136   Transcript  ENST00000280758.10           1849          1342               448         G/S  Ggc/Agc    rs1558781,COSV99774826          G  HGNC:23844  ENSP00000280758  A6QL63.129      -  UPI000051901E        A6QL63-1    tolerated_low_confidence        0.43             benign           0.022  0.1763                        -     0,1   0,1         -                     -       0.102         0         -         -              22.3        3.373019      likely_benign   0.0774              T      -0.626984               T  0.485189527273  A6QL63,A6QL63-2,A6QL63-3,H0YHR1,C9JV03  BTBDB_HUMAN,BTBDB_HUMAN,BTBDB_HUMAN,H0YHR1_HUMAN,C9JV03_HUMAN          -                               -  0.0154826749531858        0.0    A6QL63
# 3          ACKR3  P25106  VAR_085335   p.Val258Met             LP/P  rs200582844  Oculomotor-abducens synkinesis (OCABSN) [MIM:619215]    2025   V258M                          P   ENST00000272928.4  ENST00000272928  ENSP00000272928.3          NM_020311.3       NP_064707.1    NaN         rs200582844   2:236581237-236581237      A  missense_variant  MODERATE      ACKR3  ENSG00000144476   Transcript   ENST00000272928.4            898           772               258         V/M  Gtg/Atg  rs200582844,COSV56021506          G  HGNC:23692  ENSP00000272928  P25106.214      -  UPI000013D989               -                 deleterious        0.03  probably_damaging           0.978       -  pathogenic,not_provided     0,1   1,1  31211835                     -       0.494         1         -         -              26.3        4.697178          ambiguous   0.5384              D       0.143901               T  0.672353982925                                  P25106                                                    ACKR3_HUMAN     585134  no_assertion_criteria_provided   0.863086182351898        0.0    P25106
# 4          ACOD1  A6NK06  VAR_086754    p.Thr97Met             LB/B  rs767323284                                                   NaN    2025    T97M                          B   ENST00000377462.6  ENST00000377462  ENSP00000366682.1       NM_001258406.2    NP_001245335.1    NaN         rs767323284    13:76955344-76955344      T  missense_variant  MODERATE      ACOD1  ENSG00000102794   Transcript   ENST00000377462.6            338           290                97         T/M  aCg/aTg  rs767323284,COSV66291594          C  HGNC:33904  ENSP00000366682  A6NK06.110      -  UPI000015C60D               -                   tolerated        0.14  probably_damaging           0.958       -                        -     0,1   0,1  31548418                     -       0.613        -1         -         -              24.4        4.135920          ambiguous   0.3837              D       0.316682               T  0.677448093891                           A6NK06,H7C1Q4                                        IRG1_HUMAN,H7C1Q4_HUMAN          -                               -   0.957577884197235        0.0    A6NK06

# %%
merged_df.shape
# Out:
# (1116, 67)

# %%
duplicated_snps = merged_df[merged_df.duplicated('dbSNP', keep=False)]
print(duplicated_snps[['dbSNP']])
# Out:
#              dbSNP
# 307      rs2072648
# 308      rs2072648
# 332   rs1757708758
# 333   rs1757708758
# 726      rs7255187
# 727      rs7255187
# 728      rs7255187
# 737   rs1684813071
# 738   rs1684813071
# 988      rs1057149
# 989      rs1057149
# 1011  rs1385657144
# 1012  rs1385657144
# 1096  rs1965499910
# 1097  rs1965499910

# %%
cleaned_df = merged_df.drop_duplicates(subset='dbSNP', keep='first')

# %%
cleaned_df.shape
# Out:
# (1108, 67)

# %%
cleaned_df.to_csv('/home/aitanadiaz/Desktop/TFG/Cleaning data/data/humsavar/cleaned_Humsavar_with_preds_FINAL.csv', index=0)
